# %% [markdown]
# # Acquiring Beer Data
#
# From Brewerydb: https://www.brewerydb.com/

# %%
#import dependencies
import api_setup as ap
from tqdm import tqdm
import pandas as pd
from pprint import pprint

# %%
pprint(data['data'])
# Out:
# [{'abv': '6.6',
#   'available': {'description': 'Limited availability.',
#                 'id': 2,
#                 'name': 'Limited'},
#   'availableId': 2,
#   'breweries': [{'createDate': '2012-01-03 02:42:08',
#                  'description': 'The Sierra Nevada Brewing Company was '
#                                 'established in 1980 by homebrewers Ken '
#                                 'Grossman and Paul Camusi. Camusi retired in '
#                                 '1998 and sold his share in the company to '
#                                 'Grossman.\r\n'
#                                 '\r\n'
#                                 'Located in Chico, California, Sierra Nevada '
#                                 'Brewing is one of the most popular craft '
#                                 'breweries currently operating in the United '
#                                 'States. Its Pale Ale is world renowned, and '
#                                 'the brewery produces almost 700,000 barrels '
#                                 "of beer per year. Sierra Nevada's Pale Ale is "
#                                 'the second best-selling craft beer in the '
#                                 'United States, behind the Boston Beer '
#                                 "Company's Samuel Adams Boston Lager.\r\n"
#                                 '\r\n'
#                                 "Sierra Nevada's specialty brews include the "
#                                 'winter seasonal Celebration, which is similar '
#                                 'to the pale ale, but hoppier; and Summerfest, '
#                                 'a lager which is citrusy and sunny.',
#                  'established': '1980',
#                  'id': 'nHLlnK',
#                  'images': {'icon': 'https://brewerydb-images.s3.amazonaws.com/brewery/nHLlnK/upload_IClwuZ-icon.png',
#                             'large': 'https://brewerydb-images.s3.amazonaws.com/brewery/nHLlnK/upload_IClwuZ-large.png',
#                             'medium': 'https://brewerydb-images.s3.amazonaws.com/brewery/nHLlnK/upload_IClwuZ-medium.png',
#                             'squareLarge': 'https://brewerydb-images.s3.amazonaws.com/brewery/nHLlnK/upload_IClwuZ-squareLarge.png',
#                             'squareMedium': 'https://brewerydb-images.s3.amazonaws.com/brewery/nHLlnK/upload_IClwuZ-squareMedium.png'},
#                  'isInBusiness': 'Y',
#                  'isMassOwned': 'N',
#                  'isOrganic': 'N',
#                  'isVerified': 'N',
#                  'locations': [{'country': {'createDate': '2012-01-03 02:41:33',
#                                             'displayName': 'United States',
#                                             'isoCode': 'US',
#                                             'isoThree': 'USA',
#                                             'name': 'UNITED STATES',
#                                             'numberCode': 840},
#                                 'countryIsoCode': 'US',
#                                 'createDate': '2012-01-03 02:42:08',
#                                 'id': 'IaQrxj',
#                                 'inPlanning': 'N',
#                                 'isClosed': 'N',
#                                 'isPrimary': 'Y',
#                                 'latitude': 39.7246028,
#                                 'locality': 'Chico',
#                                 'locationType': 'micro',
#                                 'locationTypeDisplay': 'Micro Brewery',
#                                 'longitude': -121.8157154,
#                                 'name': 'Main Brewery',
#                                 'openToPublic': 'Y',
#                                 'phone': '530-893-3520',
#                                 'postalCode': '95928',
#                                 'region': 'California',
#                                 'status': 'verified',
#                                 'statusDisplay': 'Verified',
#                                 'streetAddress': '1075 East 20th St',
#                                 'updateDate': '2018-11-02 02:14:56',
#                                 'website': 'http://www.sierranevada.com/',
#                                 'yearOpened': '1980'},
#                                {'country': {'createDate': '2012-01-03 02:41:33',
#                                             'displayName': 'United States',
#                                             'isoCode': 'US',
#                                             'isoThree': 'USA',
#                                             'name': 'UNITED STATES',
#                                             'numberCode': 840},
#                                 'countryIsoCode': 'US',
#                                 'createDate': '2012-03-29 20:56:05',
#                                 'id': 'aqLvLE',
#                                 'inPlanning': 'N',
#                                 'isClosed': 'N',
#                                 'isPrimary': 'N',
#                                 'latitude': 35.4303824,
#                                 'locality': 'Fletcher',
#                                 'locationType': 'micro',
#                                 'locationTypeDisplay': 'Micro Brewery',
#                                 'longitude': -82.5489214,
#                                 'name': 'Asheville',
#                                 'openToPublic': 'Y',
#                                 'postalCode': '28732',
#                                 'region': 'North Carolina',
#                                 'status': 'verified',
#                                 'statusDisplay': 'Verified',
#                                 'streetAddress': '100 Sierra Nevada Way',
#                                 'timezoneId': 'America/New_York',
#                                 'updateDate': '2018-11-02 02:14:56'}],
#                  'name': 'Sierra Nevada Brewing Company',
#                  'nameShortDisplay': 'Sierra Nevada',
#                  'status': 'verified',
#                  'statusDisplay': 'Verified',
#                  'updateDate': '2018-11-02 02:15:01',
#                  'website': 'http://www.sierranevada.com/'}],
#   'createDate': '2014-05-08 11:50:47',
#   'description': 'Brewers are notorious for refusing to take the easy path. '
#                  'Instead, we lead with our hearts and pursue our passions no '
#                  'matter how difficult the road ahead. Alt Route is a tribute '
#                  'to this stubborn spirit that drove us to dodge the status '
#                  'quo and found breweries. Together we chased the siren song '
#                  'of beer with this revamped take on an antique beer style.\r\n'
#                  '\r\n'
#                  'Like us, Victory is one of the few brewers with an '
#                  'allegiance to whole-cone hops. They do extensive work with '
#                  'hop flavor, especially focusing on clever and delicious '
#                  'single-hop beers highlighting the same hop grown in '
#                  'different regions. They too share our roots in home brewing '
#                  'and never lost their passion for working with new beers and '
#                  'styles solely for the joy of making something new.',
#   'glass': {'createDate': '2012-01-03 02:41:33', 'id': 5, 'name': 'Pint'},
#   'glasswareId': 5,
#   'ibu': '50',
#   'id': 'hYaduh',
#   'isOrganic': 'N',
#   'isRetired': 'N',
#   'labels': {'contentAwareIcon': 'https://brewerydb-images.s3.amazonaws.com/beer/hYaduh/upload_MhIUer-contentAwareIcon.png',
#              'contentAwareLarge': 'https://brewerydb-images.s3.amazonaws.com/beer/hYaduh/upload_MhIUer-contentAwareLarge.png',
#              'contentAwareMedium': 'https://brewerydb-images.s3.amazonaws.com/beer/hYaduh/upload_MhIUer-contentAwareMedium.png',
#              'icon': 'https://brewerydb-images.s3.amazonaws.com/beer/hYaduh/upload_MhIUer-icon.png',
#              'large': 'https://brewerydb-images.s3.amazonaws.com/beer/hYaduh/upload_MhIUer-large.png',
#              'medium': 'https://brewerydb-images.s3.amazonaws.com/beer/hYaduh/upload_MhIUer-medium.png'},
#   'name': 'Alt Route - Beer Camp Across America',
#   'nameDisplay': 'Alt Route - Beer Camp Across America (2014)',
#   'originalGravity': '1.057',
#   'status': 'verified',
#   'statusDisplay': 'Verified',
#   'style': {'abvMax': '5.5',
#             'abvMin': '4.3',
#             'category': {'createDate': '2012-03-21 20:06:46',
#                          'id': 4,
#                          'name': 'German Origin Ales'},
#             'categoryId': 4,
#             'createDate': '2012-03-21 20:06:46',
#             'description': 'German-Style Altbiers are copper to dark brown '
#                            'ales, originally from the Düsseldorf area. No '
#                            'chill haze should be perceived. A variety of malts '
#                            'including wheat may be used to produce medium-low '
#                            'to medium malt aroma. Fruityester aroma can be '
#                            'low. No diacetyl aroma should be perceived. Hop '
#                            'aroma is low to medium. A variety of malts '
#                            'including wheat may be used to produce medium-low '
#                            'to medium level malty flavor. Hop flavor is low to '
#                            'medium. Hop bitterness is medium to very high '
#                            '(although the 25 to 35 IBU range is more normal '
#                            'for the majority of Altbiers from Düsseldorf). '
#                            'Fruity-ester flavors can be low. No diacetyl '
#                            'should be perceived. The overall impression is '
#                            'clean, crisp, and flavorful often with a dry '
#                            'finish. Body is medium.',
#             'fgMax': '1.014',
#             'fgMin': '1.008',
#             'ibuMax': '52',
#             'ibuMin': '25',
#             'id': 55,
#             'name': 'German-Style Altbier',
#             'ogMin': '1.044',
#             'shortName': 'Altbier',
#             'srmMax': '19',
#             'srmMin': '11',
#             'updateDate': '2015-04-07 17:08:31'},
#   'styleId': 55,
#   'updateDate': '2018-11-02 02:15:14',
#   'year': 2014},
#  {'available': {'description': 'Limited availability.',
#                 'id': 2,
#                 'name': 'Limited'},
#   'availableId': 2,
#   'breweries': [{'createDate': '2012-01-03 02:42:05',
#                  'description': 'Oskar Blues Brewery is part of the Oskar '
#                                 'Blues Grill and Brew restaurant and was '
#                                 'located in Lyons, Colorado, near the city of '
#                                 'Boulder. The brewery is now in Longmont, CO - '
#                                 'a much larger town just east of Lyons. Oskar '
#                                 'Blues is unique in that it serves '
#                                 'craft-brewed beer in cans, contrary to the '
#                                 'normal practice of bottling micro brews. The '
#                                 'brewery is owned by Dale Katechis, a native '
#                                 'of Florence, Alabama who brought canned beer '
#                                 'and southern fried foods together for an '
#                                 'interesting twist on the micro-brew pub.',
#                  'established': '1997',
#                  'id': 'q6vJUK',
#                  'images': {'icon': 'https://brewerydb-images.s3.amazonaws.com/brewery/q6vJUK/upload_wNi52r-icon.png',
#                             'large': 'https://brewerydb-images.s3.amazonaws.com/brewery/q6vJUK/upload_wNi52r-large.png',
#                             'medium': 'https://brewerydb-images.s3.amazonaws.com/brewery/q6vJUK/upload_wNi52r-medium.png',
#                             'squareLarge': 'https://brewerydb-images.s3.amazonaws.com/brewery/q6vJUK/upload_wNi52r-squareLarge.png',
#                             'squareMedium': 'https://brewerydb-images.s3.amazonaws.com/brewery/q6vJUK/upload_wNi52r-squareMedium.png'},
#                  'isInBusiness': 'Y',
#                  'isMassOwned': 'N',
#                  'isOrganic': 'N',
#                  'isVerified': 'N',
#                  'locations': [{'country': {'createDate': '2012-01-03 02:41:33',
#                                             'displayName': 'United States',
#                                             'isoCode': 'US',
#                                             'isoThree': 'USA',
#                                             'name': 'UNITED STATES',
#                                             'numberCode': 840},
#                                 'countryIsoCode': 'US',
#                                 'createDate': '2012-01-03 02:42:05',
#                                 'extendedAddress': 'Unit B',
#                                 'id': 'jnSdDd',
#                                 'inPlanning': 'N',
#                                 'isClosed': 'N',
#                                 'isPrimary': 'Y',
#                                 'latitude': 40.1389968,
#                                 'locality': 'Longmont',
#                                 'locationType': 'micro',
#                                 'locationTypeDisplay': 'Micro Brewery',
#                                 'longitude': -105.1227417,
#                                 'name': 'Main Brewery',
#                                 'openToPublic': 'Y',
#                                 'phone': '1-303-776-1914',
#                                 'postalCode': '80501',
#                                 'region': 'Colorado',
#                                 'status': 'verified',
#                                 'statusDisplay': 'Verified',
#                                 'streetAddress': '1800 Pike Rd',
#                                 'timezoneId': 'America/Denver',
#                                 'updateDate': '2018-11-02 02:14:56',
#                                 'website': 'http://www.oskarblues.com/',
#                                 'yearOpened': '1997'},
#                                {'country': {'createDate': '2012-01-03 02:41:33',
#                                             'displayName': 'United States',
#                                             'isoCode': 'US',
#                                             'isoThree': 'USA',
#                                             'name': 'UNITED STATES',
#                                             'numberCode': 840},
#                                 'countryIsoCode': 'US',
#                                 'createDate': '2012-12-13 15:22:31',
#                                 'hoursOfOperation': 'Tasting Room\r\n'
#                                                     'Monday-Sunday: '
#                                                     '12pm-8pm\r\n'
#                                                     '\r\n'
#                                                     'Free Brewery Tours\r\n'
#                                                     'Monday-Thursday: 4pm\r\n'
#                                                     'Friday-Sunday: 2pm, 3pm, '
#                                                     '4pm, 5pm',
#                                 'hoursOfOperationNotes': 'Tasting Room\r\n'
#                                                          'Monday-Sunday: '
#                                                          '12pm-8pm\r\n'
#                                                          '\r\n'
#                                                          'Free Brewery '
#                                                          'Tours\r\n'
#                                                          'Monday-Thursday: '
#                                                          '4pm\r\n'
#                                                          'Friday-Sunday: 2pm, '
#                                                          '3pm, 4pm, 5pm',
#                                 'id': 'I1q8kK',
#                                 'inPlanning': 'N',
#                                 'isClosed': 'N',
#                                 'isPrimary': 'N',
#                                 'latitude': 35.2534666,
#                                 'locality': 'Brevard',
#                                 'locationType': 'micro',
#                                 'locationTypeDisplay': 'Micro Brewery',
#                                 'longitude': -82.706852,
#                                 'name': 'Brevard',
#                                 'openToPublic': 'Y',
#                                 'phone': '(828) 883-2337',
#                                 'postalCode': '28712',
#                                 'region': 'North Carolina',
#                                 'status': 'verified',
#                                 'statusDisplay': 'Verified',
#                                 'streetAddress': '342 Mountain Industrial Dr.',
#                                 'updateDate': '2018-11-02 02:14:56',
#                                 'website': 'http://www.oskarblues.com/',
#                                 'yearOpened': '2012'},
#                                {'country': {'createDate': '2012-01-03 02:41:33',
#                                             'displayName': 'United States',
#                                             'isoCode': 'US',
#                                             'isoThree': 'USA',
#                                             'name': 'UNITED STATES',
#                                             'numberCode': 840},
#                                 'countryIsoCode': 'US',
#                                 'createDate': '2017-03-16 05:29:16',
#                                 'extendedAddress': '#150',
#                                 'hoursOfOperation': 'Mon - Fri: 6pm\r\n'
#                                                     'Sat - Sun: 2pm and 5pm',
#                                 'hoursOfOperationExplicit': {'fri': [{'endTime': '10:00pm',
#                                                                       'startTime': '12:00pm'}],
#                                                              'sat': [{'endTime': '10:00pm',
#                                                                       'startTime': '12:00pm'}],
#                                                              'sun': [{'endTime': '8:00pm',
#                                                                       'startTime': '12:00pm'}],
#                                                              'thu': [{'endTime': '10:00pm',
#                                                                       'startTime': '12:00pm'}],
#                                                              'tue': [{'endTime': '10:00pm',
#                                                                       'startTime': '12:00pm'}],
#                                                              'wed': [{'endTime': '10:00pm',
#                                                                       'startTime': '12:00pm'}]},
#                                 'hoursOfOperationExplicitString': 'sun-12:00pm-8:00pm,tue-12:00pm-10:00pm,wed-12:00pm-10:00pm,thu-12:00pm-10:00pm,fri-12:00pm-10:00pm,sat-12:00pm-10:00pm',
#                                 'hoursOfOperationNotes': 'Mon - Fri: 6pm\r\n'
#                                                          'Sat - Sun: 2pm and '
#                                                          '5pm',
#                                 'id': 'TkDbDx',
#                                 'inPlanning': 'N',
#                                 'isClosed': 'N',
#                                 'isPrimary': 'N',
#                                 'latitude': 30.3835422,
#                                 'locality': 'Austin',
#                                 'locationType': 'micro',
#                                 'locationTypeDisplay': 'Micro Brewery',
#                                 'longitude': -97.7142293,
#                                 'name': 'Oskar Blues',
#                                 'openToPublic': 'Y',
#                                 'phone': '(512) 243-7054',
#                                 'postalCode': '78758',
#                                 'region': 'Texas',
#                                 'status': 'verified',
#                                 'statusDisplay': 'Verified',
#                                 'streetAddress': '10420 Metric Blvd',
#                                 'timezoneId': 'America/Chicago',
#                                 'updateDate': '2018-11-02 02:14:56',
#                                 'website': 'https://www.oskarblues.com/brewery/austin',
#                                 'yearOpened': '2016'},
#                                {'country': {'createDate': '2012-01-03 02:41:33',
#                                             'displayName': 'United States',
#                                             'isoCode': 'US',
#                                             'isoThree': 'USA',
#                                             'name': 'UNITED STATES',
#                                             'numberCode': 840},
#                                 'countryIsoCode': 'US',
#                                 'createDate': '2017-06-17 20:25:49',
#                                 'hoursOfOperation': 'Mon - Thurs : 12pm - 8pm '
#                                                     '(Tour at 4pm)\r\n'
#                                                     'Fri - Sat : 12pm - 10pm '
#                                                     '(Tours at 2, 3, 4, and '
#                                                     '5pm)\r\n'
#                                                     'Sun : 12pm - 8pm (Tours '
#                                                     'at 2, 3, 4, and 5pm)',
#                                 'hoursOfOperationNotes': 'Mon - Thurs : 12pm - '
#                                                          '8pm (Tour at 4pm)\r\n'
#                                                          'Fri - Sat : 12pm - '
#                                                          '10pm (Tours at 2, 3, '
#                                                          '4, and 5pm)\r\n'
#                                                          'Sun : 12pm - 8pm '
#                                                          '(Tours at 2, 3, 4, '
#                                                          'and 5pm)',
#                                 'id': 'G2jxYM',
#                                 'inPlanning': 'N',
#                                 'isClosed': 'N',
#                                 'isPrimary': 'N',
#                                 'latitude': 35.2535881,
#                                 'locality': 'Brevard',
#                                 'locationType': 'micro',
#                                 'locationTypeDisplay': 'Micro Brewery',
#                                 'longitude': -82.7067671,
#                                 'name': 'North Carolina',
#                                 'openToPublic': 'Y',
#                                 'phone': '(828) 883-2337',
#                                 'postalCode': '28712',
#                                 'region': 'North Carolina',
#                                 'status': 'deleted',
#                                 'statusDisplay': 'Deleted',
#                                 'streetAddress': '342 Mountain Industrial '
#                                                  'Drive',
#                                 'timezoneId': 'America/New_York',
#                                 'updateDate': '2018-11-02 02:14:56',
#                                 'website': 'https://www.oskarblues.com/'}],
#                  'name': 'Oskar Blues Brewery',
#                  'nameShortDisplay': 'Oskar Blues',
#                  'status': 'verified',
#                  'statusDisplay': 'Verified',
#                  'updateDate': '2018-11-02 02:15:01',
#                  'website': 'http://www.oskarblues.com/'}],
#   'createDate': '2013-05-03 21:37:58',
#   'id': '5TQX99',
#   'isOrganic': 'N',
#   'isRetired': 'N',
#   'name': 'ALTitude',
#   'nameDisplay': 'ALTitude',
#   'status': 'verified',
#   'statusDisplay': 'Verified',
#   'style': {'abvMax': '5.5',
#             'abvMin': '4.3',
#             'category': {'createDate': '2012-03-21 20:06:46',
#                          'id': 4,
#                          'name': 'German Origin Ales'},
#             'categoryId': 4,
#             'createDate': '2012-03-21 20:06:46',
#             'description': 'German-Style Altbiers are copper to dark brown '
#                            'ales, originally from the Düsseldorf area. No '
#                            'chill haze should be perceived. A variety of malts '
#                            'including wheat may be used to produce medium-low '
#                            'to medium malt aroma. Fruityester aroma can be '
#                            'low. No diacetyl aroma should be perceived. Hop '
#                            'aroma is low to medium. A variety of malts '
#                            'including wheat may be used to produce medium-low '
#                            'to medium level malty flavor. Hop flavor is low to '
#                            'medium. Hop bitterness is medium to very high '
#                            '(although the 25 to 35 IBU range is more normal '
#                            'for the majority of Altbiers from Düsseldorf). '
#                            'Fruity-ester flavors can be low. No diacetyl '
#                            'should be perceived. The overall impression is '
#                            'clean, crisp, and flavorful often with a dry '
#                            'finish. Body is medium.',
#             'fgMax': '1.014',
#             'fgMin': '1.008',
#             'ibuMax': '52',
#             'ibuMin': '25',
#             'id': 55,
#             'name': 'German-Style Altbier',
#             'ogMin': '1.044',
#             'shortName': 'Altbier',
#             'srmMax': '19',
#             'srmMin': '11',
#             'updateDate': '2015-04-07 17:08:31'},
#   'styleId': 55,
#   'updateDate': '2018-11-02 02:15:14'},
#  {'breweries': [{'createDate': '2012-01-03 02:41:52',
#                  'description': 'Founded in 1985, Dock Street Brewing Co. was '
#                                 'the first microbrewery in Philadelphia and '
#                                 'one of the first in the country.  Today, Dock '
#                                 'Street is a small artisanal brewery that '
#                                 'finds its home in a magnificent historic '
#                                 'firehouse on the corner of 50th and Baltimore '
#                                 'Ave., in a progressive, eclectic and '
#                                 'counter-culture neighborhood that reflects '
#                                 "Dock Street's philosophy.  Dock Street has a "
#                                 'rich brewing history, a reputation for '
#                                 'exceptional quality, innovation and brewing '
#                                 'distinctive beers.  Dock Street continues to '
#                                 'experiment and push the boundaries of the '
#                                 'movement it helped build.',
#                  'established': '1985',
#                  'id': 'p3YrOa',
#                  'images': {'icon': 'https://brewerydb-images.s3.amazonaws.com/brewery/p3YrOa/upload_yOXpDJ-icon.png',
#                             'large': 'https://brewerydb-images.s3.amazonaws.com/brewery/p3YrOa/upload_yOXpDJ-large.png',
#                             'medium': 'https://brewerydb-images.s3.amazonaws.com/brewery/p3YrOa/upload_yOXpDJ-medium.png',
#                             'squareLarge': 'https://brewerydb-images.s3.amazonaws.com/brewery/p3YrOa/upload_yOXpDJ-squareLarge.png',
#                             'squareMedium': 'https://brewerydb-images.s3.amazonaws.com/brewery/p3YrOa/upload_yOXpDJ-squareMedium.png'},
#                  'isInBusiness': 'Y',
#                  'isMassOwned': 'N',
#                  'isOrganic': 'N',
#                  'isVerified': 'N',
#                  'locations': [{'country': {'createDate': '2012-01-03 02:41:33',
#                                             'displayName': 'United States',
#                                             'isoCode': 'US',
#                                             'isoThree': 'USA',
#                                             'name': 'UNITED STATES',
#                                             'numberCode': 840},
#                                 'countryIsoCode': 'US',
#                                 'createDate': '2012-01-03 02:41:52',
#                                 'id': 'HFQ27P',
#                                 'inPlanning': 'N',
#                                 'isClosed': 'N',
#                                 'isPrimary': 'Y',
#                                 'latitude': 39.9477956,
#                                 'locality': 'West Philly',
#                                 'locationType': 'micro',
#                                 'locationTypeDisplay': 'Micro Brewery',
#                                 'longitude': -75.2229305,
#                                 'name': 'Main Brewery',
#                                 'openToPublic': 'Y',
#                                 'phone': '(215)-726-2337',
#                                 'postalCode': '19143',
#                                 'region': 'Pennsylvania',
#                                 'status': 'verified',
#                                 'statusDisplay': 'Verified',
#                                 'streetAddress': '701 S. 50th Street',
#                                 'updateDate': '2018-11-02 02:14:56',
#                                 'website': 'http://www.dockstreetbeer.com'}],
#                  'mailingListUrl': 'http://www.dockstreetbeer.com/Contact.html',
#                  'name': 'Dock Street Brewery',
#                  'nameShortDisplay': 'Dock Street',
#                  'status': 'verified',
#                  'statusDisplay': 'Verified',
#                  'updateDate': '2018-11-02 02:15:01',
#                  'website': 'http://www.dockstreetbeer.com'}],
#   'createDate': '2013-11-25 14:12:28',
#   'id': 'qIa0fL',
#   'isOrganic': 'N',
#   'isRetired': 'N',
#   'labels': {'contentAwareIcon': 'https://brewerydb-images.s3.amazonaws.com/beer/qIa0fL/upload_Nv9b6E-contentAwareIcon.png',
#              'contentAwareLarge': 'https://brewerydb-images.s3.amazonaws.com/beer/qIa0fL/upload_Nv9b6E-contentAwareLarge.png',
#              'contentAwareMedium': 'https://brewerydb-images.s3.amazonaws.com/beer/qIa0fL/upload_Nv9b6E-contentAwareMedium.png',
#              'icon': 'https://brewerydb-images.s3.amazonaws.com/beer/qIa0fL/upload_Nv9b6E-icon.png',
#              'large': 'https://brewerydb-images.s3.amazonaws.com/beer/qIa0fL/upload_Nv9b6E-large.png',
#              'medium': 'https://brewerydb-images.s3.amazonaws.com/beer/qIa0fL/upload_Nv9b6E-medium.png'},
#   'name': 'Amber Beer',
#   'nameDisplay': 'Amber Beer',
#   'status': 'verified',
#   'statusDisplay': 'Verified',
#   'style': {'abvMax': '6',
#             'abvMin': '4.5',
#             'category': {'createDate': '2012-03-21 20:06:45',
#                          'id': 3,
#                          'name': 'North American Origin Ales'},
#             'categoryId': 3,
#             'createDate': '2012-03-21 20:06:45',
#             'description': 'American amber/red ales range from light copper to '
#                            'light brown in color. They are characterized by '
#                            'American-variety hops used to produce the '
#                            'perception of medium hop bitterness, flavor, and '
#                            'medium aroma. Amber ales have medium-high to high '
#                            'maltiness with medium to low caramel character. '
#                            'They should have medium to medium-high body. The '
#                            'style may have low levels of fruityester flavor '
#                            'and aroma. Diacetyl can be either absent or barely '
#                            'perceived at very low levels. Chill haze is '
#                            'allowable at cold temperatures. Slight yeast haze '
#                            'is acceptable for bottle-conditioned products.',
#             'fgMax': '1.018',
#             'fgMin': '1.012',
#             'ibuMax': '40',
#             'ibuMin': '30',
#             'id': 32,
#             'name': 'American-Style Amber/Red Ale',
#             'ogMin': '1.048',
#             'shortName': 'Amber',
#             'srmMax': '18',
#             'srmMin': '11',
#             'updateDate': '2015-04-07 15:26:52'},
#   'styleId': 32,
#   'updateDate': '2018-11-02 02:15:14'},
#  {'abv': '6',
#   'breweries': [{'createDate': '2012-01-03 02:42:05',
#                  'description': 'Oskar Blues Brewery is part of the Oskar '
#                                 'Blues Grill and Brew restaurant and was '
#                                 'located in Lyons, Colorado, near the city of '
#                                 'Boulder. The brewery is now in Longmont, CO - '
#                                 'a much larger town just east of Lyons. Oskar '
#                                 'Blues is unique in that it serves '
#                                 'craft-brewed beer in cans, contrary to the '
#                                 'normal practice of bottling micro brews. The '
#                                 'brewery is owned by Dale Katechis, a native '
#                                 'of Florence, Alabama who brought canned beer '
#                                 'and southern fried foods together for an '
#                                 'interesting twist on the micro-brew pub.',
#                  'established': '1997',
#                  'id': 'q6vJUK',
#                  'images': {'icon': 'https://brewerydb-images.s3.amazonaws.com/brewery/q6vJUK/upload_wNi52r-icon.png',
#                             'large': 'https://brewerydb-images.s3.amazonaws.com/brewery/q6vJUK/upload_wNi52r-large.png',
#                             'medium': 'https://brewerydb-images.s3.amazonaws.com/brewery/q6vJUK/upload_wNi52r-medium.png',
#                             'squareLarge': 'https://brewerydb-images.s3.amazonaws.com/brewery/q6vJUK/upload_wNi52r-squareLarge.png',
#                             'squareMedium': 'https://brewerydb-images.s3.amazonaws.com/brewery/q6vJUK/upload_wNi52r-squareMedium.png'},
#                  'isInBusiness': 'Y',
#                  'isMassOwned': 'N',
#                  'isOrganic': 'N',
#                  'isVerified': 'N',
#                  'locations': [{'country': {'createDate': '2012-01-03 02:41:33',
#                                             'displayName': 'United States',
#                                             'isoCode': 'US',
#                                             'isoThree': 'USA',
#                                             'name': 'UNITED STATES',
#                                             'numberCode': 840},
#                                 'countryIsoCode': 'US',
#                                 'createDate': '2012-01-03 02:42:05',
#                                 'extendedAddress': 'Unit B',
#                                 'id': 'jnSdDd',
#                                 'inPlanning': 'N',
#                                 'isClosed': 'N',
#                                 'isPrimary': 'Y',
#                                 'latitude': 40.1389968,
#                                 'locality': 'Longmont',
#                                 'locationType': 'micro',
#                                 'locationTypeDisplay': 'Micro Brewery',
#                                 'longitude': -105.1227417,
#                                 'name': 'Main Brewery',
#                                 'openToPublic': 'Y',
#                                 'phone': '1-303-776-1914',
#                                 'postalCode': '80501',
#                                 'region': 'Colorado',
#                                 'status': 'verified',
#                                 'statusDisplay': 'Verified',
#                                 'streetAddress': '1800 Pike Rd',
#                                 'timezoneId': 'America/Denver',
#                                 'updateDate': '2018-11-02 02:14:56',
#                                 'website': 'http://www.oskarblues.com/',
#                                 'yearOpened': '1997'},
#                                {'country': {'createDate': '2012-01-03 02:41:33',
#                                             'displayName': 'United States',
#                                             'isoCode': 'US',
#                                             'isoThree': 'USA',
#                                             'name': 'UNITED STATES',
#                                             'numberCode': 840},
#                                 'countryIsoCode': 'US',
#                                 'createDate': '2012-12-13 15:22:31',
#                                 'hoursOfOperation': 'Tasting Room\r\n'
#                                                     'Monday-Sunday: '
#                                                     '12pm-8pm\r\n'
#                                                     '\r\n'
#                                                     'Free Brewery Tours\r\n'
#                                                     'Monday-Thursday: 4pm\r\n'
#                                                     'Friday-Sunday: 2pm, 3pm, '
#                                                     '4pm, 5pm',
#                                 'hoursOfOperationNotes': 'Tasting Room\r\n'
#                                                          'Monday-Sunday: '
#                                                          '12pm-8pm\r\n'
#                                                          '\r\n'
#                                                          'Free Brewery '
#                                                          'Tours\r\n'
#                                                          'Monday-Thursday: '
#                                                          '4pm\r\n'
#                                                          'Friday-Sunday: 2pm, '
#                                                          '3pm, 4pm, 5pm',
#                                 'id': 'I1q8kK',
#                                 'inPlanning': 'N',
#                                 'isClosed': 'N',
#                                 'isPrimary': 'N',
#                                 'latitude': 35.2534666,
#                                 'locality': 'Brevard',
#                                 'locationType': 'micro',
#                                 'locationTypeDisplay': 'Micro Brewery',
#                                 'longitude': -82.706852,
#                                 'name': 'Brevard',
#                                 'openToPublic': 'Y',
#                                 'phone': '(828) 883-2337',
#                                 'postalCode': '28712',
#                                 'region': 'North Carolina',
#                                 'status': 'verified',
#                                 'statusDisplay': 'Verified',
#                                 'streetAddress': '342 Mountain Industrial Dr.',
#                                 'updateDate': '2018-11-02 02:14:56',
#                                 'website': 'http://www.oskarblues.com/',
#                                 'yearOpened': '2012'},
#                                {'country': {'createDate': '2012-01-03 02:41:33',
#                                             'displayName': 'United States',
#                                             'isoCode': 'US',
#                                             'isoThree': 'USA',
#                                             'name': 'UNITED STATES',
#                                             'numberCode': 840},
#                                 'countryIsoCode': 'US',
#                                 'createDate': '2017-03-16 05:29:16',
#                                 'extendedAddress': '#150',
#                                 'hoursOfOperation': 'Mon - Fri: 6pm\r\n'
#                                                     'Sat - Sun: 2pm and 5pm',
#                                 'hoursOfOperationExplicit': {'fri': [{'endTime': '10:00pm',
#                                                                       'startTime': '12:00pm'}],
#                                                              'sat': [{'endTime': '10:00pm',
#                                                                       'startTime': '12:00pm'}],
#                                                              'sun': [{'endTime': '8:00pm',
#                                                                       'startTime': '12:00pm'}],
#                                                              'thu': [{'endTime': '10:00pm',
#                                                                       'startTime': '12:00pm'}],
#                                                              'tue': [{'endTime': '10:00pm',
#                                                                       'startTime': '12:00pm'}],
#                                                              'wed': [{'endTime': '10:00pm',
#                                                                       'startTime': '12:00pm'}]},
#                                 'hoursOfOperationExplicitString': 'sun-12:00pm-8:00pm,tue-12:00pm-10:00pm,wed-12:00pm-10:00pm,thu-12:00pm-10:00pm,fri-12:00pm-10:00pm,sat-12:00pm-10:00pm',
#                                 'hoursOfOperationNotes': 'Mon - Fri: 6pm\r\n'
#                                                          'Sat - Sun: 2pm and '
#                                                          '5pm',
#                                 'id': 'TkDbDx',
#                                 'inPlanning': 'N',
#                                 'isClosed': 'N',
#                                 'isPrimary': 'N',
#                                 'latitude': 30.3835422,
#                                 'locality': 'Austin',
#                                 'locationType': 'micro',
#                                 'locationTypeDisplay': 'Micro Brewery',
#                                 'longitude': -97.7142293,
#                                 'name': 'Oskar Blues',
#                                 'openToPublic': 'Y',
#                                 'phone': '(512) 243-7054',
#                                 'postalCode': '78758',
#                                 'region': 'Texas',
#                                 'status': 'verified',
#                                 'statusDisplay': 'Verified',
#                                 'streetAddress': '10420 Metric Blvd',
#                                 'timezoneId': 'America/Chicago',
#                                 'updateDate': '2018-11-02 02:14:56',
#                                 'website': 'https://www.oskarblues.com/brewery/austin',
#                                 'yearOpened': '2016'},
#                                {'country': {'createDate': '2012-01-03 02:41:33',
#                                             'displayName': 'United States',
#                                             'isoCode': 'US',
#                                             'isoThree': 'USA',
#                                             'name': 'UNITED STATES',
#                                             'numberCode': 840},
#                                 'countryIsoCode': 'US',
#                                 'createDate': '2017-06-17 20:25:49',
#                                 'hoursOfOperation': 'Mon - Thurs : 12pm - 8pm '
#                                                     '(Tour at 4pm)\r\n'
#                                                     'Fri - Sat : 12pm - 10pm '
#                                                     '(Tours at 2, 3, 4, and '
#                                                     '5pm)\r\n'
#                                                     'Sun : 12pm - 8pm (Tours '
#                                                     'at 2, 3, 4, and 5pm)',
#                                 'hoursOfOperationNotes': 'Mon - Thurs : 12pm - '
#                                                          '8pm (Tour at 4pm)\r\n'
#                                                          'Fri - Sat : 12pm - '
#                                                          '10pm (Tours at 2, 3, '
#                                                          '4, and 5pm)\r\n'
#                                                          'Sun : 12pm - 8pm '
#                                                          '(Tours at 2, 3, 4, '
#                                                          'and 5pm)',
#                                 'id': 'G2jxYM',
#                                 'inPlanning': 'N',
#                                 'isClosed': 'N',
#                                 'isPrimary': 'N',
#                                 'latitude': 35.2535881,
#                                 'locality': 'Brevard',
#                                 'locationType': 'micro',
#                                 'locationTypeDisplay': 'Micro Brewery',
#                                 'longitude': -82.7067671,
#                                 'name': 'North Carolina',
#                                 'openToPublic': 'Y',
#                                 'phone': '(828) 883-2337',
#                                 'postalCode': '28712',
#                                 'region': 'North Carolina',
#                                 'status': 'deleted',
#                                 'statusDisplay': 'Deleted',
#                                 'streetAddress': '342 Mountain Industrial '
#                                                  'Drive',
#                                 'timezoneId': 'America/New_York',
#                                 'updateDate': '2018-11-02 02:14:56',
#                                 'website': 'https://www.oskarblues.com/'}],
#                  'name': 'Oskar Blues Brewery',
#                  'nameShortDisplay': 'Oskar Blues',
#                  'status': 'verified',
#                  'statusDisplay': 'Verified',
#                  'updateDate': '2018-11-02 02:15:01',
#                  'website': 'http://www.oskarblues.com/'}],
#   'createDate': '2016-09-13 22:00:03',
#   'description': 'A spiced Belgian wit that is hopped with Citra, Amarillo, '
#                  'and Simcoe multiple times in the fermenter. Spicy and '
#                  'citrusy, with fruit flavors from the yeast and hops alike, '
#                  'with a tart twist at the finish.',
#   'ibu': '55',
#   'id': 'Zd8Cxd',
#   'isOrganic': 'N',
#   'isRetired': 'N',
#   'name': 'American Summer Hoppy Wit',
#   'nameDisplay': 'American Summer Hoppy Wit',
#   'status': 'verified',
#   'statusDisplay': 'Verified',
#   'style': {'abvMax': '5.2',
#             'abvMin': '4.8',
#             'category': {'createDate': '2012-03-21 20:06:46',
#                          'id': 5,
#                          'name': 'Belgian And French Origin Ales'},
#             'categoryId': 5,
#             'createDate': '2012-03-21 20:06:46',
#             'description': 'Belgian white ales are very pale in color and are '
#                            'brewed using unmalted wheat and malted barley and '
#                            'are spiced with coriander and orange peel. '
#                            'Coriander and light orange peel aroma should be '
#                            'perceived as such or as an unidentified spiciness. '
#                            'Phenolic spiciness and yeast flavors may be '
#                            'evident at mild levels. These beers are '
#                            'traditionally bottle conditioned and served '
#                            'cloudy. An unfiltered starch and yeast haze should '
#                            'be part of the appearance. The low to medium body '
#                            'should have some degree of creaminess from wheat '
#                            'starch. The style is further characterized by the '
#                            'use of noble-type hops to achieve low hop '
#                            'bitterness and little to no apparent hop flavor. '
#                            'This beer has no diacetyl and a low to medium '
#                            'fruity-ester level. Mild acidity is appropriate.',
#             'fgMax': '1.01',
#             'fgMin': '1.006',
#             'ibuMax': '17',
#             'ibuMin': '10',
#             'id': 65,
# ...
#                                 'createDate': '2015-06-17 03:32:00',
#                                 'hoursOfOperation': 'Everyday @ 11am',
#                                 'hoursOfOperationNotes': 'Everyday @ 11am',
#                                 'id': 'kDDWiR',
#                                 'inPlanning': 'N',
#                                 'isClosed': 'N',
#                                 'isPrimary': 'N',
#                                 'latitude': 39.594287,
#                                 'locality': 'Littleton',
#                                 'locationType': 'micro',
#                                 'locationTypeDisplay': 'Micro Brewery',
#                                 'longitude': -105.0246389,
#                                 'name': 'Main Brewery',
#                                 'openToPublic': 'Y',
#                                 'phone': '303.803.1380',
#                                 'postalCode': '80120',
#                                 'region': 'Colorado',
#                                 'status': 'verified',
#                                 'statusDisplay': 'Verified',
#                                 'streetAddress': '2990 Brewery Lane',
#                                 'timezoneId': 'America/Denver',
#                                 'updateDate': '2018-11-02 02:14:56',
#                                 'website': 'http://www.breckbrew.com/farmhouse'}],
#                  'name': 'Breckenridge Brewery',
#                  'nameShortDisplay': 'Breckenridge',
#                  'status': 'verified',
#                  'statusDisplay': 'Verified',
#                  'updateDate': '2018-11-02 02:15:01',
#                  'website': 'http://www.breckbrew.com/'}],
#   'createDate': '2015-02-25 13:09:05',
#   'id': 'x7GusT',
#   'isOrganic': 'N',
#   'isRetired': 'N',
#   'labels': {'contentAwareIcon': 'https://brewerydb-images.s3.amazonaws.com/beer/x7GusT/upload_E1Co0Y-contentAwareIcon.png',
#              'contentAwareLarge': 'https://brewerydb-images.s3.amazonaws.com/beer/x7GusT/upload_E1Co0Y-contentAwareLarge.png',
#              'contentAwareMedium': 'https://brewerydb-images.s3.amazonaws.com/beer/x7GusT/upload_E1Co0Y-contentAwareMedium.png',
#              'icon': 'https://brewerydb-images.s3.amazonaws.com/beer/x7GusT/upload_E1Co0Y-icon.png',
#              'large': 'https://brewerydb-images.s3.amazonaws.com/beer/x7GusT/upload_E1Co0Y-large.png',
#              'medium': 'https://brewerydb-images.s3.amazonaws.com/beer/x7GusT/upload_E1Co0Y-medium.png'},
#   'name': 'Batch #2 Barleywine',
#   'nameDisplay': 'Batch #2 Barleywine (2015)',
#   'status': 'verified',
#   'statusDisplay': 'Verified',
#   'style': {'abvMax': '12',
#             'abvMin': '8.4',
#             'category': {'createDate': '2012-03-21 20:06:45',
#                          'id': 3,
#                          'name': 'North American Origin Ales'},
#             'categoryId': 3,
#             'createDate': '2012-03-21 20:06:46',
#             'description': 'American style barley wines range from amber to '
#                            'deep copper-garnet in color and have a full body '
#                            'and high residual malty sweetness. Complexity of '
#                            'alcohols and fruity-ester characters are often '
#                            'high and counterbalanced by assertive bitterness '
#                            'and extraordinary alcohol content. Hop aroma and '
#                            'flavor are at medium to very high levels. American '
#                            'type hops are often used but not necessary for '
#                            'this style. Very low levels of diacetyl may be '
#                            'acceptable. A caramel and/or toffee aroma and '
#                            'flavor are often part of the character. Characters '
#                            'indicating oxidation, such as vinous (sometimes '
#                            'sherry-like) aromas and/or flavors, are not '
#                            'generally acceptable in American-style Barley Wine '
#                            'Ale, however if a low level of age-induced '
#                            'oxidation character harmonizes and enhances the '
#                            'overall experience this can be regarded favorably. '
#                            'Chill haze is allowable at cold temperatures.',
#             'fgMax': '1.028',
#             'fgMin': '1.024',
#             'ibuMax': '100',
#             'ibuMin': '60',
#             'id': 34,
#             'name': 'American-Style Barley Wine Ale',
#             'ogMin': '1.09',
#             'shortName': 'American Barleywine',
#             'srmMax': '22',
#             'srmMin': '11',
#             'updateDate': '2015-04-07 15:27:08'},
#   'styleId': 34,
#   'updateDate': '2018-11-02 02:15:14',
#   'year': 2015},
#  {'abv': '9',
#   'available': {'description': 'Limited availability.',
#                 'id': 2,
#                 'name': 'Limited'},
#   'availableId': 2,
#   'breweries': [{'createDate': '2012-01-03 02:42:00',
#                  'description': 'From our earliest days of striving to make '
#                                 'consistently good beer, and instead making '
#                                 'beer that ranged from vile, to barely '
#                                 'drinkable, to wonderful, to elegant, to '
#                                 'questionable-at-best. From being castigated '
#                                 'by our West Marin neighbors to finally '
#                                 "suffering an 'eviction' by our West Marin "
#                                 'septic system. From landing in the welcoming '
#                                 'arms of Petaluma, and actually getting our '
#                                 'beer into bottles, onto the streets, and into '
#                                 'the hands of sympathatic beer geeks, to '
#                                 'steadily losing less money each month. From '
#                                 'all this and more, Lagunitas Brewing Company '
#                                 'is emerging as a battle-tested brewery '
#                                 "capable of making great beer out of goat's "
#                                 'milk, brambles, and asphalt on the surface of '
#                                 'the Moon, if need be.\r\n'
#                                 '\r\n'
#                                 "As the poet once said, 'Where, but for the "
#                                 'grace of God and the kindness of strangers, '
#                                 "go I'. Where go we indeed, whatever that "
#                                 'means.',
#                  'established': '1993',
#                  'id': 'nLsoQ9',
#                  'images': {'icon': 'https://brewerydb-images.s3.amazonaws.com/brewery/nLsoQ9/upload_WqZkvw-icon.png',
#                             'large': 'https://brewerydb-images.s3.amazonaws.com/brewery/nLsoQ9/upload_WqZkvw-large.png',
#                             'medium': 'https://brewerydb-images.s3.amazonaws.com/brewery/nLsoQ9/upload_WqZkvw-medium.png',
#                             'squareLarge': 'https://brewerydb-images.s3.amazonaws.com/brewery/nLsoQ9/upload_WqZkvw-squareLarge.png',
#                             'squareMedium': 'https://brewerydb-images.s3.amazonaws.com/brewery/nLsoQ9/upload_WqZkvw-squareMedium.png'},
#                  'isInBusiness': 'Y',
#                  'isMassOwned': 'Y',
#                  'isOrganic': 'N',
#                  'isVerified': 'N',
#                  'locations': [{'country': {'createDate': '2012-01-03 02:41:33',
#                                             'displayName': 'United States',
#                                             'isoCode': 'US',
#                                             'isoThree': 'USA',
#                                             'name': 'UNITED STATES',
#                                             'numberCode': 840},
#                                 'countryIsoCode': 'US',
#                                 'createDate': '2012-01-03 02:42:00',
#                                 'hoursOfOperation': 'Wed thru Friday '
#                                                     '3:00-9:00.\r\n'
#                                                     'Sat & Sun: 1:00-7:00',
#                                 'hoursOfOperationNotes': 'Wed thru Friday '
#                                                          '3:00-9:00.\r\n'
#                                                          'Sat & Sun: 1:00-7:00',
#                                 'id': 'C0zPjd',
#                                 'inPlanning': 'N',
#                                 'isClosed': 'N',
#                                 'isPrimary': 'N',
#                                 'latitude': 38.272435,
#                                 'locality': 'Petaluma',
#                                 'locationType': 'micro',
#                                 'locationTypeDisplay': 'Micro Brewery',
#                                 'longitude': -122.662346,
#                                 'name': 'Main Brewery',
#                                 'openToPublic': 'Y',
#                                 'phone': '707 769-4495',
#                                 'postalCode': '94954',
#                                 'region': 'California',
#                                 'status': 'verified',
#                                 'statusDisplay': 'Verified',
#                                 'streetAddress': '1280 North McDowell '
#                                                  'Boulevard',
#                                 'updateDate': '2018-11-02 02:14:56',
#                                 'website': 'http://www.lagunitas.com/',
#                                 'yearOpened': '1993'},
#                                {'country': {'createDate': '2012-01-03 02:41:33',
#                                             'displayName': 'United States',
#                                             'isoCode': 'US',
#                                             'isoThree': 'USA',
#                                             'name': 'UNITED STATES',
#                                             'numberCode': 840},
#                                 'countryIsoCode': 'US',
#                                 'createDate': '2014-08-25 12:10:03',
#                                 'id': 'g2d9B7',
#                                 'inPlanning': 'N',
#                                 'isClosed': 'N',
#                                 'isPrimary': 'N',
#                                 'latitude': 41.8579099,
#                                 'locality': 'Chicago',
#                                 'locationType': 'tasting',
#                                 'locationTypeDisplay': 'Tasting Room',
#                                 'longitude': -87.691899,
#                                 'name': 'Chicago',
#                                 'openToPublic': 'Y',
#                                 'phone': '(773) 522-2503',
#                                 'postalCode': '60608',
#                                 'region': 'Illinois',
#                                 'status': 'verified',
#                                 'statusDisplay': 'Verified',
#                                 'streetAddress': '2607 West 17th St.',
#                                 'timezoneId': 'America/Chicago',
#                                 'updateDate': '2018-11-02 02:14:56',
#                                 'website': 'http://lagunitas.com/'},
#                                {'country': {'createDate': '2012-01-03 02:41:33',
#                                             'displayName': 'United States',
#                                             'isoCode': 'US',
#                                             'isoThree': 'USA',
#                                             'name': 'UNITED STATES',
#                                             'numberCode': 840},
#                                 'countryIsoCode': 'US',
#                                 'createDate': '2017-06-08 20:31:56',
#                                 'id': 's38mA2',
#                                 'inPlanning': 'N',
#                                 'isClosed': 'Y',
#                                 'isPrimary': 'Y',
#                                 'latitude': 32.7784426,
#                                 'locality': 'Charleston',
#                                 'locationType': 'tasting',
#                                 'locationTypeDisplay': 'Tasting Room',
#                                 'longitude': -79.927534,
#                                 'name': 'Charleston Taproom & Beer Sanctuary',
#                                 'openToPublic': 'N',
#                                 'phone': '843-853-4677',
#                                 'postalCode': '29401',
#                                 'region': 'South Carolina',
#                                 'status': 'verified',
#                                 'statusDisplay': 'Verified',
#                                 'streetAddress': '161 E Bay St.',
#                                 'timezoneId': 'America/New_York',
#                                 'updateDate': '2018-11-02 02:14:56'}],
#                  'name': 'Lagunitas Brewing Company',
#                  'nameShortDisplay': 'Lagunitas',
#                  'status': 'verified',
#                  'statusDisplay': 'Verified',
#                  'updateDate': '2018-11-02 02:15:01',
#                  'website': 'http://www.lagunitas.com/'}],
#   'createDate': '2015-10-12 15:10:57',
#   'id': 'JzR6cK',
#   'isOrganic': 'N',
#   'isRetired': 'N',
#   'labels': {'contentAwareIcon': 'https://brewerydb-images.s3.amazonaws.com/beer/JzR6cK/upload_SGoWbZ-contentAwareIcon.png',
#              'contentAwareLarge': 'https://brewerydb-images.s3.amazonaws.com/beer/JzR6cK/upload_SGoWbZ-contentAwareLarge.png',
#              'contentAwareMedium': 'https://brewerydb-images.s3.amazonaws.com/beer/JzR6cK/upload_SGoWbZ-contentAwareMedium.png',
#              'icon': 'https://brewerydb-images.s3.amazonaws.com/beer/JzR6cK/upload_SGoWbZ-icon.png',
#              'large': 'https://brewerydb-images.s3.amazonaws.com/beer/JzR6cK/upload_SGoWbZ-large.png',
#              'medium': 'https://brewerydb-images.s3.amazonaws.com/beer/JzR6cK/upload_SGoWbZ-medium.png'},
#   'name': 'Bavarian-Styled Doppel Weizen',
#   'nameDisplay': 'Bavarian-Styled Doppel Weizen',
#   'status': 'verified',
#   'statusDisplay': 'Verified',
#   'style': {'abvMax': '9.3',
#             'abvMin': '6.9',
#             'category': {'createDate': '2012-03-21 20:06:46',
#                          'id': 4,
#                          'name': 'German Origin Ales'},
#             'categoryId': 4,
#             'createDate': '2012-03-21 20:06:46',
#             'description': 'This style can be either pale or dark (golden to '
#                            'dark brown in color) and has a high starting '
#                            'gravity and alcohol content. The malty sweetness '
#                            'of a Weizenbock is balanced with a clove-like '
#                            'phenolic and fruity-estery banana element to '
#                            'produce a wellrounded aroma and flavor. As is true '
#                            'with all German wheat beers, hop bitterness is low '
#                            'and carbonation is high. Hop flavor and aroma are '
#                            'absent. It has a medium to full body. If dark, a '
#                            'mild roast malt character should emerge in flavor '
#                            'and to a lesser degree in the aroma. If this is '
#                            'served with yeast the beer may be appropriately '
#                            'very cloudy. No diacetyl should be perceived.',
#             'fgMax': '1.028',
#             'fgMin': '1.016',
#             'ibuMax': '35',
#             'ibuMin': '15',
#             'id': 53,
#             'name': 'South German-Style Weizenbock / Weissbock',
#             'ogMin': '1.066',
#             'shortName': 'Weizenbock',
#             'srmMax': '30',
#             'srmMin': '5',
#             'updateDate': '2015-04-07 15:30:15'},
#   'styleId': 53,
#   'updateDate': '2018-11-02 02:15:14'}]

# %%
beer_data = pd.DataFrame()
# withBreweries and withIngredients are completely empty
beer_features = ['ingredients','id', 'name', 'nameDisplay', 'abv', 'styleId', 'year', 'glasswareId','isOrganic', 'breweries', 'glasswareId', 'isRetired', 'status', 'statusDisplay']

for feature in beer_features:
    beer_data[feature]=''

count=0
for p in tqdm(range(1,24)):
    data = ap.get_data(page=p, custom='&withBreweries=Y&withIngredients=Y')
    try:
        for i in range(50):
            for feature in beer_features:
                if feature == 'breweries':
                    beer_data.set_value(count,feature,data['data'][i][feature][0]['id'])
                elif feature == 'ingredients':
                    try:
                        #print(i, data['data'][i][feature])
                        beer_data.set_value(count,feature,len(data['data'][i][feature]['hops']))
                    except Exception as e:
                        print(e)
                else:
                    try:
                        beer_data.set_value(count,feature,data['data'][i][feature])

                    except Exception as e: 
                        print(f"name:{data['data'][i]['name']}, page:{p}, item:{i}, feature:{feature}, error:{e}")
            count+=1
    except Exception as e:
        print(e)
# Out:
#   0%|          | 0/23 [00:00<?, ?it/s]/Users/MacBookPro/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:24: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /Users/MacBookPro/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:15: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   from ipykernel import kernelapp as app
# /Users/MacBookPro/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:19: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   4%|▍         | 1/23 [00:01<00:29,  1.33s/it]
# 'ingredients'
# name:'Murican Pilsner, page:1, item:0, feature:year, error:'year'
# 'ingredients'
# name:11.5° PLATO, page:1, item:1, feature:year, error:'year'
# name:11.5° PLATO, page:1, item:1, feature:glasswareId, error:'glasswareId'
# name:11.5° PLATO, page:1, item:1, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:12th Of Never, page:1, item:2, feature:year, error:'year'
# name:12th Of Never, page:1, item:2, feature:glasswareId, error:'glasswareId'
# name:12th Of Never, page:1, item:2, feature:glasswareId, error:'glasswareId'
# name:15th Anniversary Ale, page:1, item:3, feature:abv, error:'abv'
# name:15th Anniversary Ale, page:1, item:3, feature:year, error:'year'
# name:15th Anniversary Ale, page:1, item:3, feature:glasswareId, error:'glasswareId'
# name:15th Anniversary Ale, page:1, item:3, feature:glasswareId, error:'glasswareId'
# name:16 So Fine Red Wheat Wine, page:1, item:4, feature:year, error:'year'
# name:16 So Fine Red Wheat Wine, page:1, item:4, feature:glasswareId, error:'glasswareId'
# name:16 So Fine Red Wheat Wine, page:1, item:4, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:1794 The Fergal Project, page:1, item:5, feature:year, error:'year'
# name:1794 The Fergal Project, page:1, item:5, feature:glasswareId, error:'glasswareId'
# name:1794 The Fergal Project, page:1, item:5, feature:glasswareId, error:'glasswareId'
# name:17th Saison, page:1, item:6, feature:year, error:'year'
# name:17th Saison, page:1, item:6, feature:glasswareId, error:'glasswareId'
# name:17th Saison, page:1, item:6, feature:glasswareId, error:'glasswareId'
# name:18th Anniversary Belgian Tripel, page:1, item:7, feature:year, error:'year'
# name:18th Anniversary Belgian Tripel, page:1, item:7, feature:glasswareId, error:'glasswareId'
# name:18th Anniversary Belgian Tripel, page:1, item:7, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:19 - Golden Belgian Style Ale, page:1, item:8, feature:year, error:'year'
# name:19 - Golden Belgian Style Ale, page:1, item:8, feature:glasswareId, error:'glasswareId'
# name:19 - Golden Belgian Style Ale, page:1, item:8, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:1904 American Red Lager, page:1, item:9, feature:year, error:'year'
# name:1904 American Red Lager, page:1, item:9, feature:glasswareId, error:'glasswareId'
# name:1904 American Red Lager, page:1, item:9, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:2 x 4, page:1, item:10, feature:year, error:'year'
# 'ingredients'
# name:200th Anniversary Export Stout, page:1, item:11, feature:year, error:'year'
# name:200th Anniversary Export Stout, page:1, item:11, feature:glasswareId, error:'glasswareId'
# name:200th Anniversary Export Stout, page:1, item:11, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:2017 Beer Camp, page:1, item:12, feature:glasswareId, error:'glasswareId'
# name:2017 Beer Camp, page:1, item:12, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:20th Anniversary Imperial Hash IPA on Brett, page:1, item:13, feature:year, error:'year'
# name:20th Anniversary Imperial Hash IPA on Brett, page:1, item:13, feature:glasswareId, error:'glasswareId'
# name:20th Anniversary Imperial Hash IPA on Brett, page:1, item:13, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:20th Street Ale Citra, page:1, item:14, feature:styleId, error:'styleId'
# name:20th Street Ale Citra, page:1, item:14, feature:year, error:'year'
# 'ingredients'
# name:20th Street Ale Crystal, page:1, item:15, feature:styleId, error:'styleId'
# name:20th Street Ale Crystal, page:1, item:15, feature:year, error:'year'
# name:20th Street Ale Crystal, page:1, item:15, feature:glasswareId, error:'glasswareId'
# name:20th Street Ale Crystal, page:1, item:15, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:20th Street Ale Magnum, page:1, item:16, feature:styleId, error:'styleId'
# name:20th Street Ale Magnum, page:1, item:16, feature:year, error:'year'
# name:20th Street Ale Magnum, page:1, item:16, feature:glasswareId, error:'glasswareId'
# name:20th Street Ale Magnum, page:1, item:16, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:21st Anniversary, page:1, item:17, feature:year, error:'year'
# name:21st Anniversary, page:1, item:17, feature:glasswareId, error:'glasswareId'
# name:21st Anniversary, page:1, item:17, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:25th Anniversary, page:1, item:18, feature:year, error:'year'
# name:25th Anniversary, page:1, item:18, feature:glasswareId, error:'glasswareId'
# name:25th Anniversary, page:1, item:18, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:3 Weight, page:1, item:19, feature:year, error:'year'
# name:3 Weight, page:1, item:19, feature:glasswareId, error:'glasswareId'
# name:3 Weight, page:1, item:19, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:30th Anniversary - Charlie, Fred & Ken's Bock, page:1, item:20, feature:year, error:'year'
# name:30th Anniversary - Charlie, Fred & Ken's Bock, page:1, item:20, feature:glasswareId, error:'glasswareId'
# name:30th Anniversary - Charlie, Fred & Ken's Bock, page:1, item:20, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:30th Anniversary - Fritz and Ken's Ale, page:1, item:21, feature:year, error:'year'
# name:30th Anniversary - Fritz and Ken's Ale, page:1, item:21, feature:glasswareId, error:'glasswareId'
# name:30th Anniversary - Fritz and Ken's Ale, page:1, item:21, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:30th Anniversary - Grand Cru, page:1, item:22, feature:year, error:'year'
# name:30th Anniversary - Grand Cru, page:1, item:22, feature:glasswareId, error:'glasswareId'
# name:30th Anniversary - Grand Cru, page:1, item:22, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:30th Anniversary - Jack & Ken's Ale, page:1, item:23, feature:year, error:'year'
# name:30th Anniversary - Jack & Ken's Ale, page:1, item:23, feature:glasswareId, error:'glasswareId'
# name:30th Anniversary - Jack & Ken's Ale, page:1, item:23, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:35th Anniversary  - Brewer's Reserve, page:1, item:24, feature:year, error:'year'
# name:35th Anniversary  - Brewer's Reserve, page:1, item:24, feature:glasswareId, error:'glasswareId'
# name:35th Anniversary  - Brewer's Reserve, page:1, item:24, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:420 Extra Pale Ale, page:1, item:25, feature:year, error:'year'
# 'ingredients'
# name:420 Fest, page:1, item:26, feature:year, error:'year'
# name:420 Fest, page:1, item:26, feature:glasswareId, error:'glasswareId'
# name:420 Fest, page:1, item:26, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:420 Strain G13 IPA, page:1, item:27, feature:year, error:'year'
# name:420 Strain G13 IPA, page:1, item:27, feature:glasswareId, error:'glasswareId'
# name:420 Strain G13 IPA, page:1, item:27, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:471 Double IPA - Hull Melon, page:1, item:28, feature:year, error:'year'
# name:471 Double IPA - Hull Melon, page:1, item:28, feature:glasswareId, error:'glasswareId'
# name:471 Double IPA - Hull Melon, page:1, item:28, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:471 ESB - Extra Special Bitter, page:1, item:29, feature:year, error:'year'
# 'ingredients'
# name:471 IPA Barrel Series: Citra, page:1, item:30, feature:year, error:'year'
# name:471 IPA Barrel Series: Citra, page:1, item:30, feature:glasswareId, error:'glasswareId'
# name:471 IPA Barrel Series: Citra, page:1, item:30, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:471 IPA Barrel Series: Eureka!, page:1, item:31, feature:year, error:'year'
# name:471 IPA Barrel Series: Eureka!, page:1, item:31, feature:glasswareId, error:'glasswareId'
# name:471 IPA Barrel Series: Eureka!, page:1, item:31, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:471 IPA. Aggressive Hoppiness, page:1, item:32, feature:year, error:'year'
# name:471 IPA. Aggressive Hoppiness, page:1, item:32, feature:glasswareId, error:'glasswareId'
# name:471 IPA. Aggressive Hoppiness, page:1, item:32, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:471 Pilsner, page:1, item:33, feature:abv, error:'abv'
# name:471 Pilsner, page:1, item:33, feature:year, error:'year'
# name:471 Pilsner, page:1, item:33, feature:glasswareId, error:'glasswareId'
# name:471 Pilsner, page:1, item:33, feature:glasswareId, error:'glasswareId'
# name:471 Small Batch IPA, page:1, item:34, feature:year, error:'year'
# 'ingredients'
# name:5 C's IPA, page:1, item:35, feature:year, error:'year'
# name:5 C's IPA, page:1, item:35, feature:glasswareId, error:'glasswareId'
# name:5 C's IPA, page:1, item:35, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:7 Birds, page:1, item:36, feature:year, error:'year'
# name:7 Birds, page:1, item:36, feature:glasswareId, error:'glasswareId'
# name:7 Birds, page:1, item:36, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:7 Cities Pilsner, page:1, item:37, feature:year, error:'year'
# name:7 Cities Pilsner, page:1, item:37, feature:glasswareId, error:'glasswareId'
# name:7 Cities Pilsner, page:1, item:37, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:72 Imperial, page:1, item:38, feature:year, error:'year'
# name:72 Imperial, page:1, item:38, feature:glasswareId, error:'glasswareId'
# name:72 Imperial, page:1, item:38, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:A Beer Named Sue, page:1, item:39, feature:year, error:'year'
# name:A Beer Named Sue, page:1, item:39, feature:glasswareId, error:'glasswareId'
# name:A Beer Named Sue, page:1, item:39, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:A Little Sumpin' Extra, page:1, item:40, feature:year, error:'year'
# name:A Little Sumpin' Extra, page:1, item:40, feature:glasswareId, error:'glasswareId'
# name:A Little Sumpin' Extra, page:1, item:40, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:A Little Sumpin' Sumpin', page:1, item:41, feature:year, error:'year'
# 'ingredients'
# name:ABLE Best Britter, page:1, item:42, feature:year, error:'year'
# 'ingredients'
# name:Afternooner, page:1, item:43, feature:year, error:'year'
# name:Afternooner, page:1, item:43, feature:glasswareId, error:'glasswareId'
# name:Afternooner, page:1, item:43, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Agave Wheat, page:1, item:44, feature:year, error:'year'
# 'ingredients'
# name:Ale 20, page:1, item:45, feature:year, error:'year'
# name:Ale 20, page:1, item:45, feature:glasswareId, error:'glasswareId'
# name:Ale 20, page:1, item:45, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Ale Communication, page:1, item:46, feature:year, error:'year'
# name:Ale Communication, page:1, item:46, feature:glasswareId, error:'glasswareId'
# name:Ale Communication, page:1, item:46, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:All Colorado Apricot Wheat, page:1, item:47, feature:year, error:'year'
# name:All Colorado Apricot Wheat, page:1, item:47, feature:glasswareId, error:'glasswareId'
# name:All Colorado Apricot Wheat, page:1, item:47, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:All Colorado Wet Hop Pale Ale, page:1, item:48, feature:year, error:'year'
# name:All Colorado Wet Hop Pale Ale, page:1, item:48, feature:glasswareId, error:'glasswareId'
# name:All Colorado Wet Hop Pale Ale, page:1, item:48, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Alpha Dog Imperial IPA, page:1, item:49, feature:year, error:'year'
# name:Alpha Dog Imperial IPA, page:1, item:49, feature:glasswareId, error:'glasswareId'
# name:Alpha Dog Imperial IPA, page:1, item:49, feature:glasswareId, error:'glasswareId'
#   9%|▊         | 2/23 [00:02<00:27,  1.30s/it]
# 'ingredients'
# 'ingredients'
# name:ALTitude, page:2, item:1, feature:abv, error:'abv'
# name:ALTitude, page:2, item:1, feature:year, error:'year'
# name:ALTitude, page:2, item:1, feature:glasswareId, error:'glasswareId'
# name:ALTitude, page:2, item:1, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Amber Beer, page:2, item:2, feature:abv, error:'abv'
# name:Amber Beer, page:2, item:2, feature:year, error:'year'
# name:Amber Beer, page:2, item:2, feature:glasswareId, error:'glasswareId'
# name:Amber Beer, page:2, item:2, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:American Summer Hoppy Wit, page:2, item:3, feature:year, error:'year'
# name:American Summer Hoppy Wit, page:2, item:3, feature:glasswareId, error:'glasswareId'
# name:American Summer Hoppy Wit, page:2, item:3, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Añejo Tequila Barrel Aged Gubna, page:2, item:4, feature:year, error:'year'
# name:Añejo Tequila Barrel Aged Gubna, page:2, item:4, feature:glasswareId, error:'glasswareId'
# name:Añejo Tequila Barrel Aged Gubna, page:2, item:4, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Anniversary Ale, page:2, item:5, feature:year, error:'year'
# name:Anniversary Ale, page:2, item:5, feature:glasswareId, error:'glasswareId'
# name:Anniversary Ale, page:2, item:5, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Anniversary Ale, page:2, item:6, feature:year, error:'year'
# name:Anniversary Ale, page:2, item:6, feature:glasswareId, error:'glasswareId'
# name:Anniversary Ale, page:2, item:6, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Anniversary Ale 2007, page:2, item:7, feature:year, error:'year'
# name:Anniversary Ale 2007, page:2, item:7, feature:glasswareId, error:'glasswareId'
# name:Anniversary Ale 2007, page:2, item:7, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Anniversary Ale 2009, page:2, item:8, feature:year, error:'year'
# name:Anniversary Ale 2009, page:2, item:8, feature:glasswareId, error:'glasswareId'
# name:Anniversary Ale 2009, page:2, item:8, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Antwerpen Stout, page:2, item:9, feature:year, error:'year'
# name:Antwerpen Stout, page:2, item:9, feature:glasswareId, error:'glasswareId'
# name:Antwerpen Stout, page:2, item:9, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Anubis Imperial Coffee Porter, page:2, item:10, feature:year, error:'year'
# name:Anubis Imperial Coffee Porter, page:2, item:10, feature:glasswareId, error:'glasswareId'
# name:Anubis Imperial Coffee Porter, page:2, item:10, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Asian Gold Blonde, page:2, item:11, feature:year, error:'year'
# name:Asian Gold Blonde, page:2, item:11, feature:glasswareId, error:'glasswareId'
# name:Asian Gold Blonde, page:2, item:11, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Audition - Altbier, page:2, item:12, feature:year, error:'year'
# name:Audition - Altbier, page:2, item:12, feature:glasswareId, error:'glasswareId'
# name:Audition - Altbier, page:2, item:12, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Audition - Belgian-Style Blonde, page:2, item:13, feature:year, error:'year'
# name:Audition - Belgian-Style Blonde, page:2, item:13, feature:glasswareId, error:'glasswareId'
# name:Audition - Belgian-Style Blonde, page:2, item:13, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Audition - Belgian-Style Pale Ale, page:2, item:14, feature:year, error:'year'
# name:Audition - Belgian-Style Pale Ale, page:2, item:14, feature:glasswareId, error:'glasswareId'
# name:Audition - Belgian-Style Pale Ale, page:2, item:14, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Audition - Dark Ale, page:2, item:15, feature:year, error:'year'
# name:Audition - Dark Ale, page:2, item:15, feature:glasswareId, error:'glasswareId'
# name:Audition - Dark Ale, page:2, item:15, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Audition - Double IPA, page:2, item:16, feature:year, error:'year'
# name:Audition - Double IPA, page:2, item:16, feature:glasswareId, error:'glasswareId'
# name:Audition - Double IPA, page:2, item:16, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Audition - English-Style Bitter, page:2, item:17, feature:year, error:'year'
# name:Audition - English-Style Bitter, page:2, item:17, feature:glasswareId, error:'glasswareId'
# name:Audition - English-Style Bitter, page:2, item:17, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Audition - Imperial Pilsner, page:2, item:18, feature:year, error:'year'
# 'ingredients'
# name:Audition - Pale Ale, page:2, item:19, feature:year, error:'year'
# name:Audition - Pale Ale, page:2, item:19, feature:glasswareId, error:'glasswareId'
# name:Audition - Pale Ale, page:2, item:19, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Audition - Pilsner, page:2, item:20, feature:year, error:'year'
# 'ingredients'
# name:Audition - Rye Bock, page:2, item:21, feature:year, error:'year'
# name:Audition - Rye Bock, page:2, item:21, feature:glasswareId, error:'glasswareId'
# name:Audition - Rye Bock, page:2, item:21, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Audition - Scotch Ale, page:2, item:22, feature:year, error:'year'
# name:Audition - Scotch Ale, page:2, item:22, feature:glasswareId, error:'glasswareId'
# name:Audition - Scotch Ale, page:2, item:22, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Aunt Sally, page:2, item:23, feature:year, error:'year'
# name:Aunt Sally, page:2, item:23, feature:glasswareId, error:'glasswareId'
# name:Aunt Sally, page:2, item:23, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Autumn Ale, page:2, item:24, feature:year, error:'year'
# 'ingredients'
# name:Avalanche Ale, page:2, item:25, feature:year, error:'year'
# 'ingredients'
# name:Bad Luck Blonde, page:2, item:26, feature:year, error:'year'
# 'ingredients'
# name:Balls Deep, page:2, item:27, feature:abv, error:'abv'
# name:Balls Deep, page:2, item:27, feature:year, error:'year'
# name:Balls Deep, page:2, item:27, feature:glasswareId, error:'glasswareId'
# name:Balls Deep, page:2, item:27, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Baltic Anomaly, page:2, item:28, feature:year, error:'year'
# name:Baltic Anomaly, page:2, item:28, feature:glasswareId, error:'glasswareId'
# name:Baltic Anomaly, page:2, item:28, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Baltic Joy, page:2, item:29, feature:year, error:'year'
# name:Baltic Joy, page:2, item:29, feature:glasswareId, error:'glasswareId'
# name:Baltic Joy, page:2, item:29, feature:glasswareId, error:'glasswareId'
# name:Bamberg Helles, page:2, item:30, feature:year, error:'year'
# name:Bamberg Helles, page:2, item:30, feature:glasswareId, error:'glasswareId'
# name:Bamberg Helles, page:2, item:30, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Banana Stand, page:2, item:31, feature:abv, error:'abv'
# name:Banana Stand, page:2, item:31, feature:year, error:'year'
# name:Banana Stand, page:2, item:31, feature:glasswareId, error:'glasswareId'
# name:Banana Stand, page:2, item:31, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Bare Knuckle Stout, page:2, item:32, feature:abv, error:'abv'
# name:Bare Knuckle Stout, page:2, item:32, feature:year, error:'year'
# name:Bare Knuckle Stout, page:2, item:32, feature:glasswareId, error:'glasswareId'
# name:Bare Knuckle Stout, page:2, item:32, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Barrel Aged 471 IPA. Aggressive Hoppiness, page:2, item:33, feature:year, error:'year'
# name:Barrel Aged 471 IPA. Aggressive Hoppiness, page:2, item:33, feature:glasswareId, error:'glasswareId'
# name:Barrel Aged 471 IPA. Aggressive Hoppiness, page:2, item:33, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Barrel Aged BOTL Cap, page:2, item:34, feature:year, error:'year'
# name:Barrel Aged BOTL Cap, page:2, item:34, feature:glasswareId, error:'glasswareId'
# name:Barrel Aged BOTL Cap, page:2, item:34, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Barrel Aged Chaka (Merlot), page:2, item:35, feature:year, error:'year'
# name:Barrel Aged Chaka (Merlot), page:2, item:35, feature:glasswareId, error:'glasswareId'
# name:Barrel Aged Chaka (Merlot), page:2, item:35, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Barrel Aged Dale's Pale Ale (Makers Mark), page:2, item:36, feature:year, error:'year'
# name:Barrel Aged Dale's Pale Ale (Makers Mark), page:2, item:36, feature:glasswareId, error:'glasswareId'
# name:Barrel Aged Dale's Pale Ale (Makers Mark), page:2, item:36, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Barrel Aged Imperial Cherry Stout, page:2, item:37, feature:year, error:'year'
# name:Barrel Aged Imperial Cherry Stout, page:2, item:37, feature:glasswareId, error:'glasswareId'
# name:Barrel Aged Imperial Cherry Stout, page:2, item:37, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Barrel Aged Mama's Mama's Little Yella Pils (Tequila), page:2, item:38, feature:year, error:'year'
# name:Barrel Aged Mama's Mama's Little Yella Pils (Tequila), page:2, item:38, feature:glasswareId, error:'glasswareId'
# name:Barrel Aged Mama's Mama's Little Yella Pils (Tequila), page:2, item:38, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Barrel Aged Narwhal, page:2, item:39, feature:year, error:'year'
# name:Barrel Aged Narwhal, page:2, item:39, feature:glasswareId, error:'glasswareId'
# name:Barrel Aged Narwhal, page:2, item:39, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Barrel Aged Nuovo Record, page:2, item:40, feature:year, error:'year'
# name:Barrel Aged Nuovo Record, page:2, item:40, feature:glasswareId, error:'glasswareId'
# name:Barrel Aged Nuovo Record, page:2, item:40, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Barrel Aged Twenty Five, page:2, item:41, feature:year, error:'year'
# name:Barrel Aged Twenty Five, page:2, item:41, feature:glasswareId, error:'glasswareId'
# name:Barrel Aged Twenty Five, page:2, item:41, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Barrel-Aged Bigfoot (Whiskey Barrels), page:2, item:42, feature:glasswareId, error:'glasswareId'
# name:Barrel-Aged Bigfoot (Whiskey Barrels), page:2, item:42, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Barrel-Aged Hoptimum  (Trip in the Woods), page:2, item:43, feature:year, error:'year'
# name:Barrel-Aged Hoptimum  (Trip in the Woods), page:2, item:43, feature:glasswareId, error:'glasswareId'
# name:Barrel-Aged Hoptimum  (Trip in the Woods), page:2, item:43, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Barrel-Aged Porter, page:2, item:44, feature:year, error:'year'
# name:Barrel-Aged Porter, page:2, item:44, feature:glasswareId, error:'glasswareId'
# name:Barrel-Aged Porter, page:2, item:44, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Barrel-Aged Ten Fidy, page:2, item:45, feature:year, error:'year'
# name:Barrel-Aged Ten Fidy, page:2, item:45, feature:glasswareId, error:'glasswareId'
# name:Barrel-Aged Ten Fidy, page:2, item:45, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Barrel-Aged Thunder Ann, page:2, item:46, feature:abv, error:'abv'
# name:Barrel-Aged Thunder Ann, page:2, item:46, feature:year, error:'year'
# name:Barrel-Aged Thunder Ann, page:2, item:46, feature:glasswareId, error:'glasswareId'
# name:Barrel-Aged Thunder Ann, page:2, item:46, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Barrel-Aged Torpedo Extra IPA, page:2, item:47, feature:year, error:'year'
# name:Barrel-Aged Torpedo Extra IPA, page:2, item:47, feature:glasswareId, error:'glasswareId'
# name:Barrel-Aged Torpedo Extra IPA, page:2, item:47, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Batch #2 Barleywine, page:2, item:48, feature:abv, error:'abv'
# name:Batch #2 Barleywine, page:2, item:48, feature:glasswareId, error:'glasswareId'
# name:Batch #2 Barleywine, page:2, item:48, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Bavarian-Styled Doppel Weizen, page:2, item:49, feature:year, error:'year'
# name:Bavarian-Styled Doppel Weizen, page:2, item:49, feature:glasswareId, error:'glasswareId'
# name:Bavarian-Styled Doppel Weizen, page:2, item:49, feature:glasswareId, error:'glasswareId'
#  13%|█▎        | 3/23 [00:03<00:26,  1.33s/it]
# 'ingredients'
# name:Bayside Black IPA, page:3, item:0, feature:year, error:'year'
# name:Bayside Black IPA, page:3, item:0, feature:glasswareId, error:'glasswareId'
# name:Bayside Black IPA, page:3, item:0, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Beach Bum Blonde Ale, page:3, item:1, feature:year, error:'year'
# name:Beach Bum Blonde Ale, page:3, item:1, feature:glasswareId, error:'glasswareId'
# name:Beach Bum Blonde Ale, page:3, item:1, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Bearsharktopus, page:3, item:2, feature:year, error:'year'
# name:Bearsharktopus, page:3, item:2, feature:glasswareId, error:'glasswareId'
# name:Bearsharktopus, page:3, item:2, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Bearwalker Barrel Aged Double Maple, page:3, item:3, feature:year, error:'year'
# name:Bearwalker Barrel Aged Double Maple, page:3, item:3, feature:glasswareId, error:'glasswareId'
# name:Bearwalker Barrel Aged Double Maple, page:3, item:3, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Bearwalker Brown, page:3, item:4, feature:abv, error:'abv'
# name:Bearwalker Brown, page:3, item:4, feature:year, error:'year'
# name:Bearwalker Brown, page:3, item:4, feature:glasswareId, error:'glasswareId'
# name:Bearwalker Brown, page:3, item:4, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Bearwalker Maple Brown (Four Roses Barrel-Aged), page:3, item:5, feature:abv, error:'abv'
# name:Bearwalker Maple Brown (Four Roses Barrel-Aged), page:3, item:5, feature:year, error:'year'
# name:Bearwalker Maple Brown (Four Roses Barrel-Aged), page:3, item:5, feature:glasswareId, error:'glasswareId'
# name:Bearwalker Maple Brown (Four Roses Barrel-Aged), page:3, item:5, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Bearwalker Maple Nut (Eagle Rare Barrel Aged), page:3, item:6, feature:abv, error:'abv'
# name:Bearwalker Maple Nut (Eagle Rare Barrel Aged), page:3, item:6, feature:year, error:'year'
# name:Bearwalker Maple Nut (Eagle Rare Barrel Aged), page:3, item:6, feature:glasswareId, error:'glasswareId'
# name:Bearwalker Maple Nut (Eagle Rare Barrel Aged), page:3, item:6, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Beer Barrel Bourbon, page:3, item:7, feature:abv, error:'abv'
# name:Beer Barrel Bourbon, page:3, item:7, feature:year, error:'year'
# name:Beer Barrel Bourbon, page:3, item:7, feature:glasswareId, error:'glasswareId'
# name:Beer Barrel Bourbon, page:3, item:7, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Beer Camp 013: Old Cantankerous, page:3, item:8, feature:year, error:'year'
# name:Beer Camp 013: Old Cantankerous, page:3, item:8, feature:glasswareId, error:'glasswareId'
# name:Beer Camp 013: Old Cantankerous, page:3, item:8, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Beer Camp Across America, page:3, item:9, feature:glasswareId, error:'glasswareId'
# name:Beer Camp Across America, page:3, item:9, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Beer Camp Golden IPA, page:3, item:10, feature:glasswareId, error:'glasswareId'
# name:Beer Camp Golden IPA, page:3, item:10, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Beer Camp Hoppy Lager, page:3, item:11, feature:year, error:'year'
# name:Beer Camp Hoppy Lager, page:3, item:11, feature:glasswareId, error:'glasswareId'
# name:Beer Camp Hoppy Lager, page:3, item:11, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Beer Camp Tropical IPA, page:3, item:12, feature:glasswareId, error:'glasswareId'
# name:Beer Camp Tropical IPA, page:3, item:12, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Beer Camp: Atlantic-Style Vintage Ale, page:3, item:13, feature:glasswareId, error:'glasswareId'
# name:Beer Camp: Atlantic-Style Vintage Ale, page:3, item:13, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Beer Camp: Campout Porter, page:3, item:14, feature:glasswareId, error:'glasswareId'
# name:Beer Camp: Campout Porter, page:3, item:14, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Beer Camp: Dry Hopped Belgian Golden, page:3, item:15, feature:glasswareId, error:'glasswareId'
# name:Beer Camp: Dry Hopped Belgian Golden, page:3, item:15, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Beer Camp: Dry-Hopped Barleywine-Style Ale, page:3, item:16, feature:glasswareId, error:'glasswareId'
# name:Beer Camp: Dry-Hopped Barleywine-Style Ale, page:3, item:16, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Beer Camp: Dry-Hopped Berliner-Style Weisse, page:3, item:17, feature:glasswareId, error:'glasswareId'
# name:Beer Camp: Dry-Hopped Berliner-Style Weisse, page:3, item:17, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Beer Camp: Dunkle Weisse, page:3, item:18, feature:glasswareId, error:'glasswareId'
# name:Beer Camp: Dunkle Weisse, page:3, item:18, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Beer Camp: East Meets West IPA, page:3, item:19, feature:glasswareId, error:'glasswareId'
# name:Beer Camp: East Meets West IPA, page:3, item:19, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Beer Camp: Ginger Lager, page:3, item:20, feature:glasswareId, error:'glasswareId'
# name:Beer Camp: Ginger Lager, page:3, item:20, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Beer Camp: Raspberry Sundae Ale, page:3, item:21, feature:glasswareId, error:'glasswareId'
# name:Beer Camp: Raspberry Sundae Ale, page:3, item:21, feature:glasswareId, error:'glasswareId'
# name:Beer Camp: Stout of the Union, page:3, item:22, feature:year, error:'year'
# name:Beer Camp: Stout of the Union, page:3, item:22, feature:glasswareId, error:'glasswareId'
# name:Beer Camp: Stout of the Union, page:3, item:22, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Beer Camp: Thai-Style Iced Tea, page:3, item:23, feature:glasswareId, error:'glasswareId'
# name:Beer Camp: Thai-Style Iced Tea, page:3, item:23, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Beer Camp: West Coast DIPA, page:3, item:24, feature:glasswareId, error:'glasswareId'
# name:Beer Camp: West Coast DIPA, page:3, item:24, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Beer Camp: White IPA with Yuzu, page:3, item:25, feature:glasswareId, error:'glasswareId'
# name:Beer Camp: White IPA with Yuzu, page:3, item:25, feature:glasswareId, error:'glasswareId'
# name:Beer Like A Billy Goat, page:3, item:26, feature:year, error:'year'
# name:Beer Like A Billy Goat, page:3, item:26, feature:glasswareId, error:'glasswareId'
# name:Beer Like A Billy Goat, page:3, item:26, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Beerhive, page:3, item:27, feature:year, error:'year'
# 'ingredients'
# name:Beerito, page:3, item:28, feature:year, error:'year'
# name:Beerito, page:3, item:28, feature:glasswareId, error:'glasswareId'
# name:Beerito, page:3, item:28, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Belgian Black IPA - Beer Camp #94, page:3, item:29, feature:year, error:'year'
# name:Belgian Black IPA - Beer Camp #94, page:3, item:29, feature:glasswareId, error:'glasswareId'
# name:Belgian Black IPA - Beer Camp #94, page:3, item:29, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Belgian Blond, page:3, item:30, feature:year, error:'year'
# name:Belgian Blond, page:3, item:30, feature:glasswareId, error:'glasswareId'
# name:Belgian Blond, page:3, item:30, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Belgian Crush, page:3, item:31, feature:year, error:'year'
# name:Belgian Crush, page:3, item:31, feature:glasswareId, error:'glasswareId'
# name:Belgian Crush, page:3, item:31, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Belgian Style Pale Ale - Mountain Series, page:3, item:32, feature:abv, error:'abv'
# name:Belgian Style Pale Ale - Mountain Series, page:3, item:32, feature:year, error:'year'
# name:Belgian Style Pale Ale - Mountain Series, page:3, item:32, feature:glasswareId, error:'glasswareId'
# name:Belgian Style Pale Ale - Mountain Series, page:3, item:32, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Belgian-Style Blonde IPA, page:3, item:33, feature:year, error:'year'
# name:Belgian-Style Blonde IPA, page:3, item:33, feature:glasswareId, error:'glasswareId'
# name:Belgian-Style Blonde IPA, page:3, item:33, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Bella Czech Pils, page:3, item:34, feature:year, error:'year'
# name:Bella Czech Pils, page:3, item:34, feature:glasswareId, error:'glasswareId'
# name:Bella Czech Pils, page:3, item:34, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Belle Meade Bourbon Sour, page:3, item:35, feature:abv, error:'abv'
# name:Belle Meade Bourbon Sour, page:3, item:35, feature:year, error:'year'
# name:Belle Meade Bourbon Sour, page:3, item:35, feature:glasswareId, error:'glasswareId'
# name:Belle Meade Bourbon Sour, page:3, item:35, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Bernie Weisse, page:3, item:36, feature:year, error:'year'
# name:Bernie Weisse, page:3, item:36, feature:glasswareId, error:'glasswareId'
# name:Bernie Weisse, page:3, item:36, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Betsy's Revenge, page:3, item:37, feature:year, error:'year'
# name:Betsy's Revenge, page:3, item:37, feature:glasswareId, error:'glasswareId'
# name:Betsy's Revenge, page:3, item:37, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:BFD - Beer For Drinking, page:3, item:38, feature:year, error:'year'
# name:BFD - Beer For Drinking, page:3, item:38, feature:glasswareId, error:'glasswareId'
# name:BFD - Beer For Drinking, page:3, item:38, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Bigfoot, page:3, item:39, feature:glasswareId, error:'glasswareId'
# name:Bigfoot, page:3, item:39, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Bigfoot, page:3, item:40, feature:glasswareId, error:'glasswareId'
# name:Bigfoot, page:3, item:40, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Bigfoot, page:3, item:41, feature:glasswareId, error:'glasswareId'
# name:Bigfoot, page:3, item:41, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# 'ingredients'
# 'ingredients'
# 'ingredients'
# 'ingredients'
# 'ingredients'
# name:Bigfoot, page:3, item:47, feature:glasswareId, error:'glasswareId'
# name:Bigfoot, page:3, item:47, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Bigfoot, page:3, item:48, feature:glasswareId, error:'glasswareId'
# name:Bigfoot, page:3, item:48, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Bigfoot, page:3, item:49, feature:abv, error:'abv'
# name:Bigfoot, page:3, item:49, feature:glasswareId, error:'glasswareId'
# name:Bigfoot, page:3, item:49, feature:glasswareId, error:'glasswareId'
#  17%|█▋        | 4/23 [00:05<00:24,  1.30s/it]
# 'ingredients'
# name:Bigfoot, page:4, item:0, feature:glasswareId, error:'glasswareId'
# name:Bigfoot, page:4, item:0, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Bigfoot, page:4, item:1, feature:glasswareId, error:'glasswareId'
# name:Bigfoot, page:4, item:1, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Bigfoot, page:4, item:2, feature:glasswareId, error:'glasswareId'
# name:Bigfoot, page:4, item:2, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Bigfoot, page:4, item:3, feature:glasswareId, error:'glasswareId'
# name:Bigfoot, page:4, item:3, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Bigfoot, page:4, item:4, feature:year, error:'year'
# 'ingredients'
# name:Bigfoot, page:4, item:5, feature:glasswareId, error:'glasswareId'
# name:Bigfoot, page:4, item:5, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Bigfoot (2016), page:4, item:6, feature:year, error:'year'
# name:Bigfoot (2016), page:4, item:6, feature:glasswareId, error:'glasswareId'
# name:Bigfoot (2016), page:4, item:6, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Bigfoot (2018), page:4, item:7, feature:year, error:'year'
# name:Bigfoot (2018), page:4, item:7, feature:glasswareId, error:'glasswareId'
# name:Bigfoot (2018), page:4, item:7, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Bigfoot Barrel-Aged, page:4, item:8, feature:year, error:'year'
# name:Bigfoot Barrel-Aged, page:4, item:8, feature:glasswareId, error:'glasswareId'
# name:Bigfoot Barrel-Aged, page:4, item:8, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Bing Bing, page:4, item:9, feature:year, error:'year'
# name:Bing Bing, page:4, item:9, feature:glasswareId, error:'glasswareId'
# name:Bing Bing, page:4, item:9, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Bitter Oats, page:4, item:10, feature:year, error:'year'
# name:Bitter Oats, page:4, item:10, feature:glasswareId, error:'glasswareId'
# name:Bitter Oats, page:4, item:10, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Bitter Over Ewe, page:4, item:11, feature:abv, error:'abv'
# name:Bitter Over Ewe, page:4, item:11, feature:year, error:'year'
# name:Bitter Over Ewe, page:4, item:11, feature:glasswareId, error:'glasswareId'
# name:Bitter Over Ewe, page:4, item:11, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Black Brew Bae, page:4, item:12, feature:year, error:'year'
# name:Black Brew Bae, page:4, item:12, feature:glasswareId, error:'glasswareId'
# name:Black Brew Bae, page:4, item:12, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Black Cat Porter, page:4, item:13, feature:year, error:'year'
# name:Black Cat Porter, page:4, item:13, feature:glasswareId, error:'glasswareId'
# name:Black Cat Porter, page:4, item:13, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Black Cat Stout, page:4, item:14, feature:year, error:'year'
# name:Black Cat Stout, page:4, item:14, feature:glasswareId, error:'glasswareId'
# name:Black Cat Stout, page:4, item:14, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Black Crown, page:4, item:15, feature:year, error:'year'
# 'ingredients'
# name:Black Eye PA, page:4, item:16, feature:year, error:'year'
# name:Black Eye PA, page:4, item:16, feature:glasswareId, error:'glasswareId'
# name:Black Eye PA, page:4, item:16, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Black IPA, page:4, item:17, feature:year, error:'year'
# name:Black IPA, page:4, item:17, feature:glasswareId, error:'glasswareId'
# name:Black IPA, page:4, item:17, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Black IPA, page:4, item:18, feature:year, error:'year'
# name:Black IPA, page:4, item:18, feature:glasswareId, error:'glasswareId'
# name:Black IPA, page:4, item:18, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Black Lager (Hatchery Series Release #3), page:4, item:19, feature:year, error:'year'
# name:Black Lager (Hatchery Series Release #3), page:4, item:19, feature:glasswareId, error:'glasswareId'
# name:Black Lager (Hatchery Series Release #3), page:4, item:19, feature:glasswareId, error:'glasswareId'
# name:Black Mad Hatter India Pale Ale, page:4, item:20, feature:year, error:'year'
# 'ingredients'
# name:Black Mamba, page:4, item:21, feature:year, error:'year'
# name:Black Mamba, page:4, item:21, feature:glasswareId, error:'glasswareId'
# name:Black Mamba, page:4, item:21, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Black Shack Porter, page:4, item:22, feature:year, error:'year'
# 'ingredients'
# name:Black Tulip, page:4, item:23, feature:glasswareId, error:'glasswareId'
# name:Black Tulip, page:4, item:23, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Black Vapor, page:4, item:24, feature:year, error:'year'
# 'ingredients'
# name:Blackstrap Fever, page:4, item:25, feature:year, error:'year'
# name:Blackstrap Fever, page:4, item:25, feature:glasswareId, error:'glasswareId'
# name:Blackstrap Fever, page:4, item:25, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Blantons Barrel Aged Scotch Ale, page:4, item:26, feature:year, error:'year'
# name:Blantons Barrel Aged Scotch Ale, page:4, item:26, feature:glasswareId, error:'glasswareId'
# name:Blantons Barrel Aged Scotch Ale, page:4, item:26, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Blindfold, page:4, item:27, feature:year, error:'year'
# 'ingredients'
# name:Blizzicane Bock, page:4, item:28, feature:year, error:'year'
# name:Blizzicane Bock, page:4, item:28, feature:glasswareId, error:'glasswareId'
# name:Blizzicane Bock, page:4, item:28, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Blonde Ale, page:4, item:29, feature:abv, error:'abv'
# name:Blonde Ale, page:4, item:29, feature:year, error:'year'
# 'ingredients'
# name:Blood Shot, page:4, item:30, feature:year, error:'year'
# name:Blood Shot, page:4, item:30, feature:glasswareId, error:'glasswareId'
# name:Blood Shot, page:4, item:30, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Blue, page:4, item:31, feature:year, error:'year'
# 'ingredients'
# name:Blue Dream, page:4, item:32, feature:year, error:'year'
# name:Blue Dream, page:4, item:32, feature:glasswareId, error:'glasswareId'
# name:Blue Dream, page:4, item:32, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Blue Goat, page:4, item:33, feature:styleId, error:'styleId'
# name:Blue Goat, page:4, item:33, feature:year, error:'year'
# name:Blue Goat, page:4, item:33, feature:glasswareId, error:'glasswareId'
# name:Blue Goat, page:4, item:33, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Blue Ridge Red, page:4, item:34, feature:year, error:'year'
# name:Blue Ridge Red, page:4, item:34, feature:glasswareId, error:'glasswareId'
# name:Blue Ridge Red, page:4, item:34, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Blue Sunday, page:4, item:35, feature:year, error:'year'
# name:Blue Sunday, page:4, item:35, feature:glasswareId, error:'glasswareId'
# name:Blue Sunday, page:4, item:35, feature:glasswareId, error:'glasswareId'
# name:Blueberry Ale, page:4, item:36, feature:year, error:'year'
# 'ingredients'
# name:Blueberry Porter, page:4, item:37, feature:abv, error:'abv'
# name:Blueberry Porter, page:4, item:37, feature:year, error:'year'
# name:Blueberry Porter, page:4, item:37, feature:glasswareId, error:'glasswareId'
# name:Blueberry Porter, page:4, item:37, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Blueberry Saison, page:4, item:38, feature:abv, error:'abv'
# name:Blueberry Saison, page:4, item:38, feature:year, error:'year'
# name:Blueberry Saison, page:4, item:38, feature:glasswareId, error:'glasswareId'
# name:Blueberry Saison, page:4, item:38, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Bob White, page:4, item:39, feature:year, error:'year'
# name:Bob White, page:4, item:39, feature:glasswareId, error:'glasswareId'
# name:Bob White, page:4, item:39, feature:glasswareId, error:'glasswareId'
# name:Bobolink, page:4, item:40, feature:year, error:'year'
# name:Bobolink, page:4, item:40, feature:glasswareId, error:'glasswareId'
# name:Bobolink, page:4, item:40, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Bohemian Dock Street Pilsner, page:4, item:41, feature:year, error:'year'
# name:Bohemian Dock Street Pilsner, page:4, item:41, feature:glasswareId, error:'glasswareId'
# name:Bohemian Dock Street Pilsner, page:4, item:41, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Bolivia Newton John, page:4, item:42, feature:abv, error:'abv'
# name:Bolivia Newton John, page:4, item:42, feature:year, error:'year'
# name:Bolivia Newton John, page:4, item:42, feature:glasswareId, error:'glasswareId'
# name:Bolivia Newton John, page:4, item:42, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Bonnaroo Brew, page:4, item:43, feature:year, error:'year'
# 'ingredients'
# name:Boomerang, page:4, item:44, feature:year, error:'year'
# name:Boomerang, page:4, item:44, feature:glasswareId, error:'glasswareId'
# name:Boomerang, page:4, item:44, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Born Again Yesterday, page:4, item:45, feature:year, error:'year'
# name:Born Again Yesterday, page:4, item:45, feature:glasswareId, error:'glasswareId'
# name:Born Again Yesterday, page:4, item:45, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Born Yesterday, page:4, item:46, feature:year, error:'year'
# name:Born Yesterday, page:4, item:46, feature:glasswareId, error:'glasswareId'
# name:Born Yesterday, page:4, item:46, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Bosden, page:4, item:47, feature:year, error:'year'
# name:Bosden, page:4, item:47, feature:glasswareId, error:'glasswareId'
# name:Bosden, page:4, item:47, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Bottle Rocket IPA, page:4, item:48, feature:year, error:'year'
# name:Bottle Rocket IPA, page:4, item:48, feature:glasswareId, error:'glasswareId'
# name:Bottle Rocket IPA, page:4, item:48, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Bourbon Barrel Aged Imperial Stout, page:4, item:49, feature:year, error:'year'
# name:Bourbon Barrel Aged Imperial Stout, page:4, item:49, feature:glasswareId, error:'glasswareId'
# name:Bourbon Barrel Aged Imperial Stout, page:4, item:49, feature:glasswareId, error:'glasswareId'
#  22%|██▏       | 5/23 [00:07<00:26,  1.49s/it]
# 'ingredients'
# name:Bourbon Barrel Aged Imperial Stout With Coffee, page:5, item:0, feature:year, error:'year'
# name:Bourbon Barrel Aged Imperial Stout With Coffee, page:5, item:0, feature:glasswareId, error:'glasswareId'
# name:Bourbon Barrel Aged Imperial Stout With Coffee, page:5, item:0, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Bourbon Barrel Aged Maillard's Odyssey, page:5, item:1, feature:abv, error:'abv'
# name:Bourbon Barrel Aged Maillard's Odyssey, page:5, item:1, feature:year, error:'year'
# name:Bourbon Barrel Aged Maillard's Odyssey, page:5, item:1, feature:glasswareId, error:'glasswareId'
# name:Bourbon Barrel Aged Maillard's Odyssey, page:5, item:1, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Brandy Barrel-Aged Ten Fidy, page:5, item:2, feature:year, error:'year'
# name:Brandy Barrel-Aged Ten Fidy, page:5, item:2, feature:glasswareId, error:'glasswareId'
# name:Brandy Barrel-Aged Ten Fidy, page:5, item:2, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Brass & Blues, page:5, item:3, feature:year, error:'year'
# name:Brass & Blues, page:5, item:3, feature:glasswareId, error:'glasswareId'
# name:Brass & Blues, page:5, item:3, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Braupakt, page:5, item:4, feature:year, error:'year'
# name:Braupakt, page:5, item:4, feature:glasswareId, error:'glasswareId'
# name:Braupakt, page:5, item:4, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Breakfast At Chicos, page:5, item:5, feature:year, error:'year'
# name:Breakfast At Chicos, page:5, item:5, feature:glasswareId, error:'glasswareId'
# name:Breakfast At Chicos, page:5, item:5, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Breck IPA, page:5, item:6, feature:year, error:'year'
# name:Breck IPA, page:5, item:6, feature:glasswareId, error:'glasswareId'
# name:Breck IPA, page:5, item:6, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Breckenridge Christmas Ale, page:5, item:7, feature:year, error:'year'
# name:Bretthead, page:5, item:8, feature:year, error:'year'
# name:Bretthead, page:5, item:8, feature:glasswareId, error:'glasswareId'
# name:Bretthead, page:5, item:8, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# ...
# 'ingredients'
# name:Tripper Noche, page:21, item:34, feature:year, error:'year'
# name:Tripper Noche, page:21, item:34, feature:glasswareId, error:'glasswareId'
# name:Tripper Noche, page:21, item:34, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Tropical Lover, page:21, item:35, feature:year, error:'year'
# name:Tropical Lover, page:21, item:35, feature:glasswareId, error:'glasswareId'
# name:Tropical Lover, page:21, item:35, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Tropical Mama’s, page:21, item:36, feature:year, error:'year'
# name:Tropical Mama’s, page:21, item:36, feature:glasswareId, error:'glasswareId'
# name:Tropical Mama’s, page:21, item:36, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Tropical Torpedo, page:21, item:37, feature:year, error:'year'
# name:Tropical Torpedo, page:21, item:37, feature:glasswareId, error:'glasswareId'
# name:Tropical Torpedo, page:21, item:37, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:TuberFest, page:21, item:38, feature:year, error:'year'
# name:TuberFest, page:21, item:38, feature:glasswareId, error:'glasswareId'
# name:TuberFest, page:21, item:38, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Tumbler, page:21, item:39, feature:year, error:'year'
# 'ingredients'
# name:Twin Peaks, page:21, item:40, feature:year, error:'year'
# name:Twin Peaks, page:21, item:40, feature:glasswareId, error:'glasswareId'
# name:Twin Peaks, page:21, item:40, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Twisted Cedar, page:21, item:41, feature:year, error:'year'
# name:Twisted Cedar, page:21, item:41, feature:glasswareId, error:'glasswareId'
# name:Twisted Cedar, page:21, item:41, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Twisted Fish, page:21, item:42, feature:year, error:'year'
# name:Twisted Fish, page:21, item:42, feature:glasswareId, error:'glasswareId'
# name:Twisted Fish, page:21, item:42, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Two Hats Lime, page:21, item:43, feature:year, error:'year'
# name:Two Hats Lime, page:21, item:43, feature:glasswareId, error:'glasswareId'
# name:Two Hats Lime, page:21, item:43, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Two Hats Pineapple, page:21, item:44, feature:year, error:'year'
# name:Two Hats Pineapple, page:21, item:44, feature:glasswareId, error:'glasswareId'
# name:Two Hats Pineapple, page:21, item:44, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Two-Headed Ruthless Rye IPA, page:21, item:45, feature:year, error:'year'
# name:Two-Headed Ruthless Rye IPA, page:21, item:45, feature:glasswareId, error:'glasswareId'
# name:Two-Headed Ruthless Rye IPA, page:21, item:45, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Two-One Niner, page:21, item:46, feature:year, error:'year'
# 'ingredients'
# name:Uncle Bert's Farm Market Red, page:21, item:47, feature:year, error:'year'
# name:Uncle Bert's Farm Market Red, page:21, item:47, feature:glasswareId, error:'glasswareId'
# name:Uncle Bert's Farm Market Red, page:21, item:47, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Unfiltered Wheat Beer, page:21, item:48, feature:year, error:'year'
# 'ingredients'
# name:Unibrown, page:21, item:49, feature:year, error:'year'
# name:Unibrown, page:21, item:49, feature:glasswareId, error:'glasswareId'
# name:Unibrown, page:21, item:49, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Unite Red IPA, page:22, item:0, feature:abv, error:'abv'
# name:Unite Red IPA, page:22, item:0, feature:year, error:'year'
# name:Unite Red IPA, page:22, item:0, feature:glasswareId, error:'glasswareId'
# name:Unite Red IPA, page:22, item:0, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:United in Orange, page:22, item:1, feature:year, error:'year'
# name:United in Orange, page:22, item:1, feature:glasswareId, error:'glasswareId'
# name:United in Orange, page:22, item:1, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Vanilla Porter, page:22, item:2, feature:year, error:'year'
# 'ingredients'
# name:Vanilla Wheat, page:22, item:3, feature:abv, error:'abv'
# name:Vanilla Wheat, page:22, item:3, feature:year, error:'year'
# name:Vanilla Wheat, page:22, item:3, feature:glasswareId, error:'glasswareId'
# name:Vanilla Wheat, page:22, item:3, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Velvet Elvis Stout, page:22, item:4, feature:abv, error:'abv'
# name:Velvet Elvis Stout, page:22, item:4, feature:year, error:'year'
# name:Velvet Elvis Stout, page:22, item:4, feature:glasswareId, error:'glasswareId'
# name:Velvet Elvis Stout, page:22, item:4, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Vienna, page:22, item:5, feature:year, error:'year'
# name:Vienna, page:22, item:5, feature:glasswareId, error:'glasswareId'
# name:Vienna, page:22, item:5, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Vienna Lager, page:22, item:6, feature:year, error:'year'
# name:Vienna Lager, page:22, item:6, feature:glasswareId, error:'glasswareId'
# name:Vienna Lager, page:22, item:6, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Vienna Lager, page:22, item:7, feature:year, error:'year'
# name:Vienna Lager, page:22, item:7, feature:glasswareId, error:'glasswareId'
# name:Vienna Lager, page:22, item:7, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:VT Haze, page:22, item:8, feature:year, error:'year'
# name:VT Haze, page:22, item:8, feature:glasswareId, error:'glasswareId'
# name:VT Haze, page:22, item:8, feature:glasswareId, error:'glasswareId'
# name:Wachusetts IPA, page:22, item:9, feature:year, error:'year'
# 'ingredients'
# name:Waldo's Special Ale, page:22, item:10, feature:year, error:'year'
# 'ingredients'
# name:Wally, page:22, item:11, feature:year, error:'year'
# name:Wally, page:22, item:11, feature:glasswareId, error:'glasswareId'
# name:Wally, page:22, item:11, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Wally Junior, page:22, item:12, feature:year, error:'year'
# name:Wally Junior, page:22, item:12, feature:glasswareId, error:'glasswareId'
# name:Wally Junior, page:22, item:12, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Wango Mango, page:22, item:13, feature:year, error:'year'
# name:Wango Mango, page:22, item:13, feature:glasswareId, error:'glasswareId'
# name:Wango Mango, page:22, item:13, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Warrior Bomb, page:22, item:14, feature:year, error:'year'
# name:Warrior Bomb, page:22, item:14, feature:glasswareId, error:'glasswareId'
# name:Warrior Bomb, page:22, item:14, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Water-melon-Rita, page:22, item:15, feature:year, error:'year'
# name:Water-melon-Rita, page:22, item:15, feature:glasswareId, error:'glasswareId'
# name:Water-melon-Rita, page:22, item:15, feature:glasswareId, error:'glasswareId'
# name:Waterkeeper, page:22, item:16, feature:year, error:'year'
# 'ingredients'
# name:Weizenbock - Beer Camp #37, page:22, item:17, feature:year, error:'year'
# name:Weizenbock - Beer Camp #37, page:22, item:17, feature:glasswareId, error:'glasswareId'
# name:Weizenbock - Beer Camp #37, page:22, item:17, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Well Built, page:22, item:18, feature:year, error:'year'
# name:Well Built, page:22, item:18, feature:glasswareId, error:'glasswareId'
# name:Well Built, page:22, item:18, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Well Built E.S.B., page:22, item:19, feature:year, error:'year'
# name:Well Built E.S.B., page:22, item:19, feature:glasswareId, error:'glasswareId'
# name:Well Built E.S.B., page:22, item:19, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:West Latitude Session Rye, page:22, item:20, feature:year, error:'year'
# name:West Latitude Session Rye, page:22, item:20, feature:glasswareId, error:'glasswareId'
# name:West Latitude Session Rye, page:22, item:20, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Wet Hopped American Summer, page:22, item:21, feature:year, error:'year'
# name:Wet Hopped American Summer, page:22, item:21, feature:glasswareId, error:'glasswareId'
# name:Wet Hopped American Summer, page:22, item:21, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Wheat Of The Moment, page:22, item:22, feature:year, error:'year'
# name:Wheat Of The Moment, page:22, item:22, feature:glasswareId, error:'glasswareId'
# name:Wheat Of The Moment, page:22, item:22, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Wheat Wine, page:22, item:23, feature:year, error:'year'
# name:Wheat Wine, page:22, item:23, feature:glasswareId, error:'glasswareId'
# name:Wheat Wine, page:22, item:23, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Whiplash, page:22, item:24, feature:year, error:'year'
# 'ingredients'
# name:Whiskey Barrel Snowman Stout, page:22, item:25, feature:year, error:'year'
# name:Whiskey Barrel Snowman Stout, page:22, item:25, feature:glasswareId, error:'glasswareId'
# name:Whiskey Barrel Snowman Stout, page:22, item:25, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:White Ale, page:22, item:26, feature:year, error:'year'
# name:White Ale, page:22, item:26, feature:glasswareId, error:'glasswareId'
# name:White Ale, page:22, item:26, feature:glasswareId, error:'glasswareId'
# name:White Hatter, page:22, item:27, feature:year, error:'year'
# 'ingredients'
# name:White IPA - Asheville Beer Week, page:22, item:28, feature:glasswareId, error:'glasswareId'
# name:White IPA - Asheville Beer Week, page:22, item:28, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:White Lightning , page:22, item:29, feature:year, error:'year'
# name:White Lightning , page:22, item:29, feature:glasswareId, error:'glasswareId'
# name:White Lightning , page:22, item:29, feature:glasswareId, error:'glasswareId'
# name:Whole Lotta Lov, page:22, item:30, feature:year, error:'year'
# name:Whole Lotta Lov, page:22, item:30, feature:glasswareId, error:'glasswareId'
# name:Whole Lotta Lov, page:22, item:30, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Why Not?, page:22, item:31, feature:year, error:'year'
# name:Why Not?, page:22, item:31, feature:glasswareId, error:'glasswareId'
# name:Why Not?, page:22, item:31, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Wicked Wheat IPA , page:22, item:32, feature:year, error:'year'
# name:Wicked Wheat IPA , page:22, item:32, feature:glasswareId, error:'glasswareId'
# name:Wicked Wheat IPA , page:22, item:32, feature:glasswareId, error:'glasswareId'
# name:Wicket IPA, page:22, item:33, feature:year, error:'year'
# name:Wicket IPA, page:22, item:33, feature:glasswareId, error:'glasswareId'
# name:Wicket IPA, page:22, item:33, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Wilco Tango Foxtrot, page:22, item:34, feature:year, error:'year'
# 'ingredients'
# name:Wild Blue Blueberry Lager, page:22, item:35, feature:year, error:'year'
# name:Wild Blue Blueberry Lager, page:22, item:35, feature:glasswareId, error:'glasswareId'
# name:Wild Blue Blueberry Lager, page:22, item:35, feature:glasswareId, error:'glasswareId'
# name:Wild Thang, page:22, item:36, feature:year, error:'year'
# name:Wild Thang, page:22, item:36, feature:glasswareId, error:'glasswareId'
# name:Wild Thang, page:22, item:36, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Willett Bourbon Barrel Aged Imperial Stout, page:22, item:37, feature:year, error:'year'
# name:Willett Bourbon Barrel Aged Imperial Stout, page:22, item:37, feature:glasswareId, error:'glasswareId'
# name:Willett Bourbon Barrel Aged Imperial Stout, page:22, item:37, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Willettized Coffee Stout, page:22, item:38, feature:year, error:'year'
# name:Willettized Coffee Stout, page:22, item:38, feature:glasswareId, error:'glasswareId'
# name:Willettized Coffee Stout, page:22, item:38, feature:glasswareId, error:'glasswareId'
# 'ingredients'
#  96%|█████████▌| 22/23 [00:31<00:01,  1.44s/it]
# name:Willettized Imperial Coffee Stout, page:22, item:39, feature:year, error:'year'
# name:Willettized Imperial Coffee Stout, page:22, item:39, feature:glasswareId, error:'glasswareId'
# name:Willettized Imperial Coffee Stout, page:22, item:39, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Winter Ale, page:22, item:40, feature:year, error:'year'
# name:Winter Ale, page:22, item:40, feature:glasswareId, error:'glasswareId'
# name:Winter Ale, page:22, item:40, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Winter Haze, page:22, item:41, feature:year, error:'year'
# 'ingredients'
# name:Winter Saison, page:22, item:42, feature:year, error:'year'
# name:Winter Saison, page:22, item:42, feature:glasswareId, error:'glasswareId'
# name:Winter Saison, page:22, item:42, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Wintertide Ale, page:22, item:43, feature:year, error:'year'
# name:Wintertide Ale, page:22, item:43, feature:glasswareId, error:'glasswareId'
# name:Wintertide Ale, page:22, item:43, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Witbier with Grapefruit, page:22, item:44, feature:year, error:'year'
# name:Witbier with Grapefruit, page:22, item:44, feature:glasswareId, error:'glasswareId'
# name:Witbier with Grapefruit, page:22, item:44, feature:glasswareId, error:'glasswareId'
# name:Witness, page:22, item:45, feature:year, error:'year'
# name:Witness, page:22, item:45, feature:glasswareId, error:'glasswareId'
# name:Witness, page:22, item:45, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Wookie Down, page:22, item:46, feature:year, error:'year'
# name:Wookie Down, page:22, item:46, feature:glasswareId, error:'glasswareId'
# name:Wookie Down, page:22, item:46, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Work, page:22, item:47, feature:abv, error:'abv'
# name:Work, page:22, item:47, feature:glasswareId, error:'glasswareId'
# name:Work, page:22, item:47, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:WTFarmhouse, page:22, item:48, feature:year, error:'year'
# name:WTFarmhouse, page:22, item:48, feature:glasswareId, error:'glasswareId'
# name:WTFarmhouse, page:22, item:48, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:XMas Chub, page:22, item:49, feature:year, error:'year'
# name:XMas Chub, page:22, item:49, feature:glasswareId, error:'glasswareId'
# name:XMas Chub, page:22, item:49, feature:glasswareId, error:'glasswareId'
# 100%|██████████| 23/23 [00:31<00:00,  1.15s/it]
# 'ingredients'
# name:Xtra Time, page:23, item:0, feature:year, error:'year'
# name:Xtra Time, page:23, item:0, feature:glasswareId, error:'glasswareId'
# name:Xtra Time, page:23, item:0, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Yadig? Berliner Hopfenweissen, page:23, item:1, feature:year, error:'year'
# name:Yadig? Berliner Hopfenweissen, page:23, item:1, feature:glasswareId, error:'glasswareId'
# name:Yadig? Berliner Hopfenweissen, page:23, item:1, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Year of the Dog - Release #1, page:23, item:2, feature:year, error:'year'
# name:Year of the Dog - Release #1, page:23, item:2, feature:glasswareId, error:'glasswareId'
# name:Year of the Dog - Release #1, page:23, item:2, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Yippe Rye Aye!, page:23, item:3, feature:year, error:'year'
# 'ingredients'
# 'ingredients'
# 'ingredients'
# name:Zepher Ale, page:23, item:6, feature:styleId, error:'styleId'
# name:Zepher Ale, page:23, item:6, feature:year, error:'year'
# 'ingredients'
# name:ZiegenBock Amber, page:23, item:7, feature:year, error:'year'
# name:ZiegenBock Amber, page:23, item:7, feature:glasswareId, error:'glasswareId'
# name:ZiegenBock Amber, page:23, item:7, feature:glasswareId, error:'glasswareId'
# 'ingredients'
# name:Zoomer, page:23, item:8, feature:year, error:'year'
# name:Zoomer, page:23, item:8, feature:glasswareId, error:'glasswareId'
# name:Zoomer, page:23, item:8, feature:glasswareId, error:'glasswareId'
# list index out of range
# list index out of range

# %%
beer_data[beer_data['ingredients'].notna()]
# Out:
#      ingredients      id                                name  \
# 3              5  xwYSL2                15th Anniversary Ale
# 4              4  UJGpVS           16 So Fine Red Wheat Wine
# 6              4  LcpeBb                         17th Saison
# 7              3  Yd8G8r     18th Anniversary Belgian Tripel
# 34             4  j9cp5e                 471 Small Batch IPA
# 80             1  YXPOTZ                      Bamberg Helles
# 122            2  lT9g7O       Beer Camp: Stout of the Union
# 126            1  gFe3ro              Beer Like A Billy Goat
# 170            3  E6kkPh     Black Mad Hatter India Pale Ale
# 186            3  932XO8                       Blueberry Ale
# 190            1  qpPzL7                            Bobolink
# 208            1  RcyKuX                           Bretthead
# 218            1  qGhR1j                             Bud Ice
# 220            1  dimtrs                           Bud Light
# 223            1  t9aucT                   Bud Light Chelada
# 225            1  MzoCPz                      Bud Light Lime
# 226            1  VwOYAS          Bud Light Lime Mang-O-Rita
# 228            1  hd8yE8                  Bud Light Platinum
# 232            1  1P45iR                           Budweiser
# 235            1  eW9IJb                   Budweiser Chelada
# 244            2  QhHBBX                               Busch
# 245            2  fKinUP                           Busch Ice
# 246            2  30zzKy                         Busch Light
# 247            2  vNwXnT        Busch Signature Copper Lager
# 248            2  zYJxUM                         Cabin Fever
# 255            3  KY5gtZ                     Celebration Ale
# 273            1  3wh93y                           Chewbocka
# 291            1  h2d5zt                            Conehead
# 296            3  ehb1eB                    Country Pale Ale
# 318           13  69tWZj                  Dank Tank Ghoulash
# ...          ...     ...                                 ...
# 703            5  9XJBp9                           Narconaut
# 704            2  Rg6aeS                             Narwhal
# 725            4  Cwuozg          Nitro Vanilla Porter (NVP)
# 731            3  OhhDEr                  Nooner Session IPA
# 739            2  N9aJxO  Oak Aged Mad Hatter India Pale Ale
# 756            2  lr1zya                             Old Ale
# 757            2  jChDlj             Old Chico Crystal Wheat
# 776            2  Lx7DEm                 Ovila Abbey Trippel
# 789            3  cdkpyx                            Pale Ale
# 791            1  bnURKM                            Paleooza
# 820            2  bFMDB3               Portsmouth Barleywine
# 834            3  OAko81                            R. Prime
# 851            2  0UTcHS                       Ripley Tripel
# 871            3  zTJ86p                          Rye Hatter
# 937            3  zJigjF                         Spinnerbait
# 954            2  LfwcEu                   Sugarshack Saison
# 955            3  h9JXAb                          Summer Ale
# 965            3  2Bxz64                              Sundog
# 972            4  uzOl1k                      SweetWater IPA
# 977            4  XeZfaD                       T.L.A. I.P.A.
# 981            2  YmuNgG                    Tasmanian Hatter
# 993            3  vf8QTx                     Terra Incognita
# 1006           2  eVgnFV                            The Poet
# 1059           1  8rc5kA                      Wachusetts IPA
# 1066           2  6jvc3G                         Waterkeeper
# 1077           4  gQiQsk                        White Hatter
# 1080           1  rRe2jl                     Whole Lotta Lov
# 1083           2  655f2d                          Wicket IPA
# 1086           3  kzMoR5                          Wild Thang
# 1095           1  KiXHLV                             Witness
#
#                              nameDisplay   abv styleId year glasswareId  \
# 3                   15th Anniversary Ale   NaN       5  NaN         NaN
# 4              16 So Fine Red Wheat Wine    11      35  NaN         NaN
# 6                            17th Saison     9      72  NaN         NaN
# 7        18th Anniversary Belgian Tripel    10      59  NaN         NaN
# 34                   471 Small Batch IPA   9.2      30  NaN           8
# 80                        Bamberg Helles   5.2      86  NaN         NaN
# 122        Beer Camp: Stout of the Union     7      42  NaN         NaN
# 126               Beer Like A Billy Goat   6.5      89  NaN         NaN
# 170      Black Mad Hatter India Pale Ale  5.56      41  NaN           5
# 186                        Blueberry Ale   4.5     119  NaN           5
# 190                             Bobolink   6.7      72  NaN         NaN
# 208                            Bretthead   6.1      30  NaN         NaN
# 218                              Bud Ice   5.5      97  NaN         NaN
# 220                            Bud Light   4.2      94  NaN           5
# 223                    Bud Light Chelada   4.2      94  NaN           5
# 225                       Bud Light Lime   4.2      94  NaN           5
# 226           Bud Light Lime Mang-O-Rita     8     161  NaN         NaN
# 228                   Bud Light Platinum     6      94  NaN           5
# 232                            Budweiser     5      93  NaN           5
# 235                    Budweiser Chelada     5      93  NaN           5
# 244                                Busch   4.6      93  NaN           5
# 245                            Busch Ice   5.9      99  NaN           5
# 246                          Busch Light   4.1      94  NaN           5
# 247         Busch Signature Copper Lager   5.7      93  NaN           5
# 248                          Cabin Fever   6.5      37  NaN           5
# 255                      Celebration Ale   6.8      26  NaN           5
# 273                            Chewbocka   6.2      88  NaN         NaN
# 291                             Conehead   5.7      30  NaN         NaN
# 296                     Country Pale Ale   5.1      25  NaN           5
# 318                   Dank Tank Ghoulash   8.5      31  NaN           5
# ...                                  ...   ...     ...  ...         ...
# 703                            Narconaut   6.6      30  NaN         NaN
# 704                              Narwhal  10.2      43  NaN           6
# 725           Nitro Vanilla Porter (NVP)   4.7      18  NaN         NaN
# 731                   Nooner Session IPA   4.8      30  NaN           5
# 739   Oak Aged Mad Hatter India Pale Ale  7.22      31  NaN           5
# 756                              Old Ale   6.9      13  NaN         NaN
# 757              Old Chico Crystal Wheat   4.8      25  NaN           5
# 776                  Ovila Abbey Trippel   8.8      59  NaN         NaN
# 789                             Pale Ale   5.6      25  NaN           5
# 791                             Paleooza   4.4      25  NaN           5
# 820                Portsmouth Barleywine    11      34  NaN           8
# 834                             R. Prime   6.2      30  NaN         NaN
# 851                        Ripley Tripel   9.6      59  NaN         NaN
# 871                           Rye Hatter  6.12     112  NaN           5
# 937                          Spinnerbait     6      57  NaN         NaN
# 954                    Sugarshack Saison   5.1      72  NaN         NaN
# 955                           Summer Ale   4.7     113  NaN           9
# 965                               Sundog   4.5      32  NaN           5
# 972                       SweetWater IPA   6.3      30  NaN           5
# 977                        T.L.A. I.P.A.   5.7      30  NaN         NaN
# 981                     Tasmanian Hatter     7      30  NaN           5
# 993                      Terra Incognita   8.5     125  NaN           8
# 1006                            The Poet   5.2      21  NaN           5
# 1059                      Wachusetts IPA   5.6      30  NaN           5
# 1066                         Waterkeeper     6      48  NaN           9
# 1077                        White Hatter   5.5      62  NaN           5
# 1080                     Whole Lotta Lov   5.4      20  NaN         NaN
# 1083                          Wicket IPA   5.4       2  NaN         NaN
# 1086                          Wild Thang     5      36  NaN         NaN
# 1095                             Witness     6      65  NaN         NaN
#
#      isOrganic breweries isRetired    status statusDisplay
# 3            N    TMc6H2         N  verified      Verified
# 4            N    TMc6H2         N  verified      Verified
# 6            N    TMc6H2         N  verified      Verified
# 7            N    TMc6H2         N  verified      Verified
# 34           N    IImUD9         N  verified      Verified
# 80           N    VEY3Xa         N  verified      Verified
# 122          N    nHLlnK         N  verified      Verified
# 126          N    VEY3Xa         N  verified      Verified
# 170          N    AqEUBQ         N  verified      Verified
# 186          N    DifSi4         N  verified      Verified
# 190          N    VEY3Xa         N  verified      Verified
# 208          N    VEY3Xa         N  verified      Verified
# 218          N    BznahA         N  verified      Verified
# 220          N    BznahA         N  verified      Verified
# 223          N    BznahA         N  verified      Verified
# 225          N    BznahA         N  verified      Verified
# 226          N    BznahA         N  verified      Verified
# 228          N    BznahA         N  verified      Verified
# 232          N    BznahA         N  verified      Verified
# 235          N    BznahA         N  verified      Verified
# 244          N    BznahA         N  verified      Verified
# 245          N    BznahA         N  verified      Verified
# 246          N    BznahA         N  verified      Verified
# 247          N    BznahA         N  verified      Verified
# 248          N    AqEUBQ         N  verified      Verified
# 255          N    nHLlnK         N  verified      Verified
# 273          N    VEY3Xa         N  verified      Verified
# 291          N    VEY3Xa         N  verified      Verified
# 296          N    DifSi4         N  verified      Verified
# 318          N    TMc6H2         N  verified      Verified
# ...        ...       ...       ...       ...           ...
# 703          N    VEY3Xa         N  verified      Verified
# 704          N    nHLlnK         N  verified      Verified
# 725          N    IImUD9         N  verified      Verified
# 731          N    nHLlnK         N  verified      Verified
# 739          N    AqEUBQ         N  verified      Verified
# 756          N    VEY3Xa         N  verified      Verified
# 757          N    nHLlnK         N  verified      Verified
# 776          N    nHLlnK         N  verified      Verified
# 789          N    nHLlnK         N  verified      Verified
# 791          N    AqEUBQ         N  verified      Verified
# 820          N    4F7QA9         N  verified      Verified
# 834          N    VEY3Xa         N  verified      Verified
# 851          N    VEY3Xa         N  verified      Verified
# 871          N    AqEUBQ         N  verified      Verified
# 937          N    TMc6H2         N  verified      Verified
# 954          N    4F7QA9         N  verified      Verified
# 955          N    DifSi4         N  verified      Verified
# 965          N    AqEUBQ         N  verified      Verified
# 972          N    TMc6H2         N  verified      Verified
# 977          N    VEY3Xa         N  verified      Verified
# 981          N    AqEUBQ         N  verified      Verified
# 993          N    nHLlnK         N  verified      Verified
# 1006         N    AqEUBQ         N  verified      Verified
# 1059         N    DifSi4         N  verified      Verified
# 1066         N    TMc6H2         N  verified      Verified
# 1077         N    AqEUBQ         N  verified      Verified
# 1080         N    VEY3Xa         N  verified      Verified
# 1083         N    VEY3Xa         N  verified      Verified
# 1086         N    4F7QA9         N  verified      Verified
# 1095         N    VEY3Xa         N  verified      Verified
#
# [82 rows x 13 columns]

# %% [markdown]
# > we'll change the column names from camel case to snake case for better consistency in notebook

# %%
beer_data.rename(columns={'id':'beer_id', 'nameDisplay':'display_name','isOrganic':'organic','isRetired':'retired','breweries':'brewery_id', 'styleId':'style_id', 'glasswareId':'glass_id'}, inplace=True)

# %%
beer_data.drop('statusDisplay',axis=1, inplace=True)

# %%
beer_data.shape
# Out:
# (1109, 11)

# %%
beer_data.head()
# Out:
#   beer_id                       name               display_name  abv style_id  \
# 0  c4f2KE           'Murican Pilsner           'Murican Pilsner  5.5       98
# 1  zTTWa2                11.5° PLATO                11.5° PLATO  4.5      164
# 2  zfP2fK              12th Of Never              12th Of Never  5.5       25
# 3  xwYSL2       15th Anniversary Ale       15th Anniversary Ale  NaN        5
# 4  UJGpVS  16 So Fine Red Wheat Wine  16 So Fine Red Wheat Wine   11       35
#
#   year glass_id organic brewery_id retired    status
# 0  NaN        4       N     nHLlnK       N  verified
# 1  NaN      NaN       N     nHLlnK       N  verified
# 2  NaN      NaN       N     nLsoQ9       N  verified
# 3  NaN      NaN       N     TMc6H2       N  verified
# 4  NaN      NaN       N     TMc6H2       N  verified

# %%
beer_data.to_csv("data/beers.csv")

# %% [markdown]
# > we can see that there are 263 beers of the 1109 total beers that have a value for glass_id

# %%
beer_glass = beer_data[beer_data["glass_id"].notna()]
print(beer_glass.shape)
beer_glass.head()
# Out:
# (263, 11)
#    beer_id                            name                    display_name  \
# 0   c4f2KE                'Murican Pilsner                'Murican Pilsner
# 10  qGDeH1                           2 x 4                           2 x 4
# 14  uIgENV           20th Street Ale Citra           20th Street Ale Citra
# 25  NoNhan              420 Extra Pale Ale              420 Extra Pale Ale
# 29  fa0oqf  471 ESB - Extra Special Bitter  471 ESB - Extra Special Bitter
#
#     abv style_id year glass_id organic brewery_id retired    status
# 0   5.5       98  NaN        4       N     nHLlnK       N  verified
# 10  8.7       70  NaN        5       N     nHLlnK       N  verified
# 14  7.3      NaN  NaN        5       N     nHLlnK       N  verified
# 25  5.4       25  NaN        5       N     TMc6H2       N  verified
# 29  7.8        5  NaN        5       N     IImUD9       Y  verified

# %% [markdown]
# > Below, we can see the distribution of the glasses. The majority of the beers use glass5. Because of the lack of data in several other glass_id's, it would not be safe to generalize the data over other beers/glasses

# %%
beer_glass.groupby('glass_id').count()['beer_id']
# Out:
# glass_id
# 1      1
# 2      1
# 3      4
# 4     15
# 5    214
# 6      9
# 8     15
# 9      4
# Name: beer_id, dtype: int64

# %% [markdown]
# > before we can create our plots, we need to clean the data and make sure that the data types are consistent with the requirements for the plot.

# %%
# beer_glass.info() 
# shows that all variables are categorical and abv should be turned into a float and glass_id to int to be able to plot
beer_glass['abv'] = beer_glass['abv'].astype(float)
beer_glass['glass_id'] = beer_glass['glass_id'].astype(int)
beer_glass.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 263 entries, 0 to 1106
# Data columns (total 11 columns):
# beer_id         263 non-null object
# name            263 non-null object
# display_name    263 non-null object
# abv             259 non-null float64
# style_id        258 non-null object
# year            20 non-null object
# glass_id        263 non-null int64
# organic         263 non-null object
# brewery_id      263 non-null object
# retired         263 non-null object
# status          263 non-null object
# dtypes: float64(1), int64(1), object(9)
# memory usage: 24.7+ KB
# /Users/MacBookPro/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/MacBookPro/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
abv_glass = beer_glass.boxplot('abv', "glass_id")

# %%
abv_hist = beer_glass.plot(y='abv', kind='hist', bins=20, title='Alcohol by Volume', legend=False)
